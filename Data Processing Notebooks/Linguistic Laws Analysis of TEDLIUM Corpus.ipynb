# %%
import os
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
#directory = "/Users/test/Desktop/Audio Vox Datasets and References/TEDLIUM_release1/train/stm"
directory = "/Volumes/LaCie/WORKING MATERIALS/TEDLIUM/train/stm"
FILE_LIST = []
for root, subdirectories, files in os.walk(directory):
    for file in files:
        file_name = os.path.join(file)
        ID = file_name
        FILE_LIST.append(ID)
        
TALK_IDs = list(set(FILE_LIST))
print(len(TALK_IDs))
# Out:
# 774

# %%
## LIMIT THE NUMER OF SPEAKERS IN TALK IDS TO CONTROL FOR SPEAKER VARIABILITY

# %%
'''random.shuffle(TALK_IDs)
TALK_IDs = TALK_IDs[:40]'''
# Out:
# 'random.shuffle(TALK_IDs)\nTALK_IDs = TALK_IDs[:40]'

# %%
TALK_IDs
# Out:
# ['DavidPogue_2008P.stm',
#  'JeffHan_2006.stm',
#  'AlexTabarrok_2009.stm',
#  'HeatherKnight_2010W.stm',
#  'ElizabethPisani_2010.stm',
#  'TomHoney_2005.stm',
#  'KiranBirSethi_2009I.stm',
#  'ZainabSalbi_2010G.stm',
#  'MathieuLehanneur_2009G.stm',
#  'RayKurzweil_2009U.stm',
#  'HansRosling_2009I.stm',
#  'JohnWalker_2007P.stm',
#  'SebastianSeung_2010G.stm',
#  'GaryLauder_2010.stm',
#  'RobertWright_2009P.stm',
#  'TimFerriss_2008P.stm',
#  'NeilGershenfeld_2006.stm',
#  'JimFallon_2009.stm',
#  'PaulMacCready_2003.stm',
#  'AubreydeGrey_2005G.stm',
#  'PatrickAwuah_2007G.stm',
#  'NoraYorkWHATIWANT_2006S.stm',
#  'NeilTurok_2008.stm',
#  'JohnHardy_2010G.stm',
#  'KimGorgens_2010X.stm',
#  'ThomasGoetz_2010P.stm',
#  'JohnMaeda_2007.stm',
#  'RichardBaraniuk_2006.stm',
#  'SugataMitra_2010G.stm',
#  'KateOrff_2010W.stm',
#  'MichaelMerzenich_2004.stm',
#  'AJJacobs_2007P.stm',
#  'JakobTrollback_2007.stm',
#  'MarcusduSautoy_2009G.stm',
#  'PaulRomer_2009G.stm',
#  'PaolaAntonelli_2007P.stm',
#  'LaurieGarrett_2007U.stm',
#  'SamMartin_2009G.stm',
#  'RodneyBrooks_2003.stm',
#  'CarlSafina_2010X.stm',
#  'NormanFoster_2007P.stm',
#  'MelindaGates_2010X.stm',
#  'PhilZimbardo_2008.stm',
#  'SharmeenObaidChinoy_2010U.stm',
#  'EdwardBurtynsky_2009G.stm',
#  'EvanWilliams_2009.stm',
#  'KevinSurace_2009.stm',
#  'LakshmiPratury_2007.stm',
#  'WoodyNorris_2004.stm',
#  'EmilyPilloton_2010G.stm',
#  'DavidDeutsch_2009G.stm',
#  'DeborahGordon_2003.stm',
#  'GregStone_2010Z.stm',
#  'Rives4AM_2007.stm',
#  'SunithaKrishnan_2009I.stm',
#  'DanDennett_2002.stm',
#  'HansRosling_2009.stm',
#  'ChrisAnderson_2004.stm',
#  'KarenArmstrong_2009G.stm',
#  'MichaelPritchard_2009G.stm',
#  'YvesBehar_2008.stm',
#  'BrianGreene_2005.stm',
#  'HansRosling_2006.stm',
#  'LisaMargonelli_2010X.stm',
#  'KaryMullis_2002.stm',
#  'DonNorman_2003.stm',
#  'FieldsWickerMiurin_2009S.stm',
#  'EllenDunhamJones_2010X.stm',
#  'PeterEigen_2009X.stm',
#  'BeckyBlanton_2009G.stm',
#  'DanAriely_2009.stm',
#  'JoachimdePosada_2009U.stm',
#  'HodLipson_2007.stm',
#  'EuvinNaidoo_2007G.stm',
#  'LawrenceLessig_2010X.stm',
#  'EveEnsler_2009I.stm',
#  'LaliteshKattragadda_2009I.stm',
#  'SpencerWells_2007G.stm',
#  'ThomasBarnett_2005.stm',
#  'CynthiaSchneider_2009G.stm',
#  'YossiVardi_2007.stm',
#  'JohnGerzema_2009X.stm',
#  'MajoraCarter_2006.stm',
#  'SusanShaw_2010X.stm',
#  'BlaiseAguerayArcas_2010.stm',
#  'CharlesElachi_2008P.stm',
#  'DeanKamen_2009P.stm',
#  'NandanNilekani_2009.stm',
#  'PenelopeBoston_2006.stm',
#  'AlanSiegel_2010.stm',
#  'DavidBismark_2010G.stm',
#  'LouiseLeakey_2008.stm',
#  'SirKenRobinson_2010.stm',
#  'KeithBellows_2002.stm',
#  'WilliamUry_2010X.stm',
#  'GeorgeAyittey_2007G.stm',
#  'ThomasThwaites_2010S.stm',
#  'LizColeman_2009.stm',
#  'TempleGrandin_2010.stm',
#  'HelenFisher_2008.stm',
#  'SusanBlackmore_2008.stm',
#  'JanePoynter_2009.stm',
#  'KatherineFulton_2007.stm',
#  'IanDunbar_2007P.stm',
#  'DeborahScranton_2007.stm',
#  'JohnUnderkoffler_2010.stm',
#  'KevinStone_2010U.stm',
#  'OryOkolloh_2007G.stm',
#  'Saraswati_2009P.stm',
#  'JamesBalog_2009G.stm',
#  'PaulCollier_2009S.stm',
#  'DavidHanson_2009.stm',
#  'EthanZuckerman_2010G.stm',
#  'LesleyHazleton_2010X.stm',
#  'KeithBarry_2004.stm',
#  'PeterHaas_2010G.stm',
#  'BreneBrown_2010X.stm',
#  'DavidHolt_2004.stm',
#  'JohnMaeda_2008P.stm',
#  'NateSilver_2009.stm',
#  'WillieSmits_2009.stm',
#  'EvaVertes_2005.stm',
#  'JaneGoodall_2002.stm',
#  'VanJones_2010X.stm',
#  'MishaGlenny_2009G.stm',
#  'PaulMoller_2004.stm',
#  'DavidGriffin_2008.stm',
#  'ElaineMorgan_2009G.stm',
#  'GregLynn_2005.stm',
#  'EmmanuelJal_2009G.stm',
#  'NickVeasey_2009G.stm',
#  'ReedKroloff_2003.stm',
#  'JasonClay_2010G.stm',
#  'BruceFeiler_2010P.stm',
#  'JohnFrancis_2008.stm',
#  'PeterHirshberg_2007P.stm',
#  'YvesBehar_2009.stm',
#  'CraigVenter_2005G.stm',
#  'TanLe_2010G.stm',
#  'SherwinNuland_2001.stm',
#  'RachelArmstrong_2009G.stm',
#  'IsaacMizrahi_2008.stm',
#  'RichardPyle_2004.stm',
#  'RobertLang_2008.stm',
#  'MichaelPollan_2007.stm',
#  'MichaelMilken_2001.stm',
#  'DanielGoleman_2007.stm',
#  'LarryBurns_2005.stm',
#  'OlafurEliasson_2009.stm',
#  'EnricSala_2010Z.stm',
#  'DeborahRhodes_2010W.stm',
#  'GeroMiesenboeck_2010G.stm',
#  'JayWalker_2008.stm',
#  'RobertNeuwirth_2005.stm',
#  'BurtRutan_2006.stm',
#  'BeauLotto_2009G.stm',
#  'EddiReaderWHATYOUDO_2004.stm',
#  'IrwinRedlener_2008.stm',
#  'LennartGreen_2005.stm',
#  'NathanMyhrvold_2007.stm',
#  'DerekSivers_2010U.stm',
#  'EveEnsler_2004.stm',
#  'MichaelShermer_2010.stm',
#  'CharlesLimb_2010X.stm',
#  'CameronSinclair_2006.stm',
#  'EWidder_2010Z.stm',
#  'GeverTulley_2009.stm',
#  'StevenLevitt_2004.stm',
#  'TierneyThys_2003.stm',
#  'CharlesAnderson_2009I.stm',
#  'ChrisAbani_2008.stm',
#  'SebastianWernicke_2010A.stm',
#  'JohnKasaona_2010.stm',
#  'RobDunbar_2010Z.stm',
#  'SeyiOyesola_2007G.stm',
#  'ShimonSteinberg_2010X.stm',
#  'RomulusWhitaker_2009I.stm',
#  'MajoraCarter_2010X.stm',
#  'JeffHawkins_2003.stm',
#  'PaulSereno_2005.stm',
#  'MarkBittman_2007P.stm',
#  'GarikIsraelian_2009G.stm',
#  'FeisalAbdulRauf_2009P.stm',
#  'RichardBranson_2007.stm',
#  'StefanSagmeister_2008.stm',
#  'NaifAlMutawa_2010G.stm',
#  'GregoryPetsko_2008.stm',
#  'KaryMullis_2009.stm',
#  'PeterDiamandis_2008.stm',
#  'StevenCowley_2009G.stm',
#  'BjarkeIngels_2009G.stm',
#  'DorisKearnsGoodwin_2008.stm',
#  'JanChipchase_2007.stm',
#  'CarolynSteel_2009G.stm',
#  'GaryWolf_2010S.stm',
#  'StuartBrown_2008P.stm',
#  'StevenStrogatz_2004R.stm',
#  'GeorgeSmoot_2008P.stm',
#  'StephenHawking_2008.stm',
#  'KartickSatyanarayan_2009I.stm',
#  'MartinRees_2005G.stm',
#  'AriannaHuffington_2010W.stm',
#  'SusanSavageRumbaugh_2004.stm',
#  'JeffreySkoll_2007.stm',
#  'PameliaKurstin_2002.stm',
#  'RennyGleeson_2009.stm',
#  'MalcolmGladwell_2004.stm',
#  'RichardPreston_2008.stm',
#  'JimmyWales_2005G.stm',
#  'SirKenRobinson_2006.stm',
#  'MitchellJoachim_2010.stm',
#  'ScottKim_2008P.stm',
#  'JamesForbes_2009P.stm',
#  'JillSobuleMANHATTANINJANUARY_2006.stm',
#  'RichardSears_2010U.stm',
#  'ClayShirky_2005G.stm',
#  'RorySutherland_2009G.stm',
#  'ChristopherMcDougall_2010X.stm',
#  'RobertBallard_2008.stm',
#  'StephenPetranek_2002.stm',
#  'LarryBrilliant_2006.stm',
#  'DavidPogue_2006.stm',
#  'BobThurman_2006S.stm',
#  'AdamGrosser_2007.stm',
#  'DavidBolinsky_2007.stm',
#  'ClayShirky_2010S.stm',
#  'JoseAntonioAbreu_2009.stm',
#  'SergeyBrin_2004.stm',
#  'JonathanHarris_2007.stm',
#  'JoelLevine_2009X.stm',
#  'JimToomey_2010Z.stm',
#  'BertrandPiccard_2009G.stm',
#  'DanielPink_2009G.stm',
#  'AdamSadowsky_2010X.stm',
#  'LewisPugh_2009G.stm',
#  'PeterDiamandis_2005G.stm',
#  'WillardWigan_2009G.stm',
#  'BillJoy_2006.stm',
#  'JackieTabick_2009P.stm',
#  'RichardStJohn_2009U.stm',
#  'MechaiViravaidya_2010X.stm',
#  'NickBostrom_2005G.stm',
#  'FelixDennis_2004.stm',
#  'RavinAgrawal_2009I.stm',
#  'DavidGallo_1998.stm',
#  'JaimeLerner_2007.stm',
#  'RayKurzweil_2005.stm',
#  'RoyGould_2008.stm',
#  'AnthonyAtala_2009P.stm',
#  'PaulDebevec_2009X.stm',
#  'BillGross_2003.stm',
#  'Naturally7FLYBABY_2009.stm',
#  'AndrewMwenda_2007G.stm',
#  'ChipConley_2010.stm',
#  'PhilipHoward_2010.stm',
#  'IngeMissmahl_2010G.stm',
#  'DavidKeith_2007S.stm',
#  'JayWalker_2009.stm',
#  'JillSobuleandJuliaSweeneySHOW_2007.stm',
#  'JoeDeRisi_2006.stm',
#  'MichaelMoschen_2002.stm',
#  'MarcPachter_2008P.stm',
#  'ChrisAbani_2007G.stm',
#  'GrahamHill_2010.stm',
#  'RobForbes_2006.stm',
#  'HeribertWatzke_2010G.stm',
#  'EvaZeisel_2001.stm',
#  'GolanLevin_2004.stm',
#  'JonathanHaidt_2008.stm',
#  'DeanOrnish_2004.stm',
#  'RichardSt.John_2005.stm',
#  'EdwardBurtynsky_2005.stm',
#  'GregoryStock_2003.stm',
#  'RivesTTYL_2008.stm',
#  'EvanGrant_2009G.stm',
#  'CharityTillemannDick_2010P.stm',
#  'JuliaSweeney_2010.stm',
#  'CatherineMohr_2010U.stm',
#  'KevinKelly_2007P.stm',
#  'EvelynGlennie_2003.stm',
#  'JehaneNoujaim_2006.stm',
#  'JacquelineNovogratz_2009U.stm',
#  'DaveEggers_2008.stm',
#  'LeeSmolin_2003.stm',
#  'PeterReinhart_2008P.stm',
#  'DanGilbert_2004.stm',
#  'BillDavenhall_2009P.stm',
#  'EdUlbrich_2009.stm',
#  'KarenArmstrong_2008.stm',
#  'ParagKhanna_2009G.stm',
#  'NellieMcKayCLONIE_2008.stm',
#  'TomChatfield_2010G.stm',
#  'JohnDoerr_2007.stm',
#  'TonyRobbins_2006.stm',
#  'AlGore_2006.stm',
#  'MartinJacques_2010S.stm',
#  'JamesSurowiecki_2005.stm',
#  'BenoitMandelbrot_2010.stm',
#  'HansRosling_2009S.stm',
#  'NoahFeldman_2003.stm',
#  'DavidBlaine_2009P.stm',
#  'NatalieJeremijenko_2009P.stm',
#  'ArthurBenjamin_2009.stm',
#  'DianeBenscoter_2009U.stm',
#  'PatrickChappatte_2010G.stm',
#  'JacquelineNovogratz_2009S.stm',
#  'MiltonGlaser_1998.stm',
#  'HelenFisher_2006.stm',
#  'SamanthaPower_2008.stm',
#  'IqbalQuadir_2005G.stm',
#  'TonyPorter_2010W.stm',
#  'TorstenReil_2003.stm',
#  'StewartBrand_2009S.stm',
#  'AlGore_2008.stm',
#  'JillTarter_2009.stm',
#  'NaliniNadkarni_2010U.stm',
#  'JamaisCascio_2006.stm',
#  'MallikaSarabhai_2009I.stm',
#  'HannaRosin_2010W.stm',
#  'PhilZimbardo_2009U.stm',
#  'BenSaunders_2005.stm',
#  'TheoJansen_2007.stm',
#  'UrsusWehrli_2006.stm',
#  'SherylSandberg_2010W.stm',
#  'WillWright_2007.stm',
#  'BrianSkerry_2010Z.stm',
#  'DeanOrnish_2006.stm',
#  'NeilPasricha_2010X.stm',
#  'EbenBayer_2010G.stm',
#  'PaulRothemund_2007.stm',
#  'JohnDelaney_2010Z.stm',
#  'AimeeMullins_2009U.stm',
#  'RozSavage_2010Z.stm',
#  'DavidMcCandless_2010G.stm',
#  'KenKamler_2009P.stm',
#  'BjornLomborg_2005.stm',
#  'EricDishman_2009P.stm',
#  'TeresaCarrenoOrchestra_2009.stm',
#  'RAMashelkar_2009I.stm',
#  'VilayanurRamachandran_2009I.stm',
#  'GrahamHawkes_2005.stm',
#  'SheenaIyengar_2010G.stm',
#  'NathanWolfe_2009.stm',
#  'ChimamandaAdichie_2009G.stm',
#  'EricSanderson_2009G.stm',
#  'RossLovegrove_2005.stm',
#  'KakiKing_2008.stm',
#  'HisHolinessTheKarmapa_2009I.stm',
#  'JoAnnKucheraMorin_2009.stm',
#  'NatalieMerchant_2010.stm',
#  'ArthurPottsDawson_2010G.stm',
#  'EricBerlow_2010G.stm',
#  'JuanEnriquez_2009.stm',
#  'ScottMcCloud_2005.stm',
#  'DavidRockwell_2002.stm',
#  'Jennifer8Lee_2008P.stm',
#  'CameronHerold_2009X.stm',
#  'TimJackson_2010G.stm',
#  'RobertWright_2006.stm',
#  'RichardDawkins_2005G.stm',
#  'JonathanHarris_2007P.stm',
#  'JonathanKlein_2010U.stm',
#  'SarahJones_2009.stm',
#  'WilliamKamkwamba_2009G.stm',
#  'OliverSacks_2009.stm',
#  'RachelPike_2009G.stm',
#  'SherwinNuland_2003.stm',
#  'AdoraSvitak_2010.stm',
#  'MarisaFickJordan_2007G2.stm',
#  'EleniGabreMadhin_2007G.stm',
#  'JulianTreasure_2009G.stm',
#  'DanBarber_2008P.stm',
#  'PaolaAntonelli_2007.stm',
#  'MarianBantjes_2010.stm',
#  'JamilAbuWardeh_2010G.stm',
#  'MairaKalman_2007.stm',
#  'TheRaspyniBrothers_2002.stm',
#  'CharlesLeadbeater_2010S.stm',
#  'EstherDuflo_2010.stm',
#  'MichaelSandel_2010.stm',
#  'VikMuniz_2003.stm',
#  'BrunoBowden_2008.stm',
#  'SethPriebatsch_2010X.stm',
#  'FrancoSacchi_2007G.stm',
#  'StefanWolff_2010G.stm',
#  'StewartBrand_2006.stm',
#  'MurrayGellMannLANGUAGE_2007.stm',
#  'RobHopkins_2009G.stm',
#  'KristenAshburn_2003.stm',
#  'MiruKim_2008P.stm',
#  'StewartBrand_2004.stm',
#  'AliCarrChellman_2010X.stm',
#  'WilliamMcDonough_2005.stm',
#  'SiegfriedWoldhek_2008.stm',
#  'AnupamMishra_2009I.stm',
#  'DavidHoffman_2008.stm',
#  'FransLanting_2005.stm',
#  'JasonFried_2010X.stm',
#  'VilayanurRamachandran_2007.stm',
#  'DanDennett_2006.stm',
#  'ShimonSchocken_2010X.stm',
#  'GeoffMulgan_2009G.stm',
#  'ThomasDolby_2010.stm',
#  'CKWilliams_2001.stm',
#  'StefanSagmeister_2009G.stm',
#  'RaghavaKK_2010.stm',
#  'RobertFull_2009.stm',
#  'BarrySchuler_2008P.stm',
#  'IanGoldin_2009G.stm',
#  'KRamdas_2009I.stm',
#  'StevenJohnson_2010G.stm',
#  'DanielKraft_2009.stm',
#  'JacekUtko_2009.stm',
#  'DanDennett_2009U.stm',
#  'GeorgeWhitesides_2009X.stm',
#  'PeterGabriel_2006.stm',
#  'RoryBremner_2009G.stm',
#  'PaulMacCready_1998.stm',
#  'CorneilleEwango_2007G.stm',
#  'StewBLACKMENSKI_2006.stm',
#  'KiranBedi_2010W.stm',
#  'ZeresenayAlemseged_2007G.stm',
#  'NicholasChristakis_2010.stm',
#  'ElizabethLesser_2010W.stm',
#  'NellieMcKayFEMINISTSIF_2008.stm',
#  'VirginiaPostrel_2004.stm',
#  'RebeccaSaxe_2009G.stm',
#  'DavidHoffman_2007.stm',
#  'AshrafGhani_2005G.stm',
#  'JohannaBlakley_2010W.stm',
#  'EvgenyMorozov_2009G.stm',
#  'CameronSinclair_2009G.stm',
#  'MattRidley_2010G.stm',
#  'DanDennett_2003.stm',
#  'NicholasNegroponte_2007P.stm',
#  'TimBernersLee_2010U.stm',
#  'JoshuaPrinceRamus_2006.stm',
#  'JaneGoodall_2007G.stm',
#  'NgoziOkonjoIweala_2007G.stm',
#  'YochaiBenkler_2005G.stm',
#  'BenjaminZander_2008.stm',
#  'BartWeetjens_2010X.stm',
#  'ChrisBangle_2002.stm',
#  'MagnusLarsson_2009G.stm',
#  'CharlesMoore_2009U.stm',
#  'AaronHuey_2010X.stm',
#  'LizaDonnelly_2010W.stm',
#  'PaulEwald_2007.stm',
#  'ThulasirajRavilla_2009I.stm',
#  'ConradWolfram_2010G.stm',
#  'NancyEtcoff_2004.stm',
#  'MaryRoach_2009.stm',
#  'RayAnderson_2009.stm',
#  'AlaindeBotton_2009G.stm',
#  'LucaTurin_2005.stm',
#  'AditiShankardass_2009I.stm',
#  'CraigVenter_2010P.stm',
#  'NewtonAduaka_2007G.stm',
#  'JessaGamble_2010GU.stm',
#  'JohanRockstrom_2010G.stm',
#  'DavidSRose_2007U.stm',
#  'RorySutherland_2010S.stm',
#  'RivesINTERNET_2006S.stm',
#  'MikeRowe_2008P.stm',
#  'DeanOrnish_2008.stm',
#  'HowardRheingold_2005.stm',
#  'GordonBrown_2009G.stm',
#  'JJAbrams_2007.stm',
#  'RachelBotsman_2010X.stm',
#  'ElifShafak_2010G.stm',
#  'PhilippeStarck_2007.stm',
#  'ArthurGanson_2004.stm',
#  'KamalMeattle_2009U.stm',
#  'BruceBuenodeMesquita_2009.stm',
#  'HansRosling_2010S.stm',
#  'FrankGehry_1990.stm',
#  'JohnnyLee_2008.stm',
#  'JulianTreasure_2010GU.stm',
#  'TheLXD_2010.stm',
#  'KevinBales_2010.stm',
#  'TomShannon_2009S.stm',
#  'ZeFrank_2004.stm',
#  'BenCameron_2010X.stm',
#  'CarmenAgraDeedy_2005.stm',
#  'DavidLogan_2009.stm',
#  'PeterDonnelly_2005G.stm',
#  'RufusGriscomandAlisaVolkman_2010W.stm',
#  'JoshuaPrinceRamus_2009X.stm',
#  'RaulMidonEVERYBODY_2007.stm',
#  'LewisPugh_2010G.stm',
#  'DianaLaufenberg_2010X.stm',
#  'MenaTrott_2006.stm',
#  'RaulMidonANSWERS_2007.stm',
#  'ShaiAgassi_2009.stm',
#  'JacquelineNovogratz_2007G.stm',
#  'ChrisAnderson_2002.stm',
#  'AlexisOhanian_2009I.stm',
#  'BirkeBaehr_2010X.stm',
#  'JeffBezos_2003.stm',
#  'CliffordStoll_2006.stm',
#  'DevduttPattanaik_2009I.stm',
#  'EricGiler_2009G.stm',
#  'BartonSeaver_2010Z.stm',
#  'RobertFischell_2005.stm',
#  'ChristopherDeam_2002.stm',
#  'LarryBrilliant_2007P.stm',
#  'RachelSussman_2010G.stm',
#  'BarrySchwartz_2009.stm',
#  'CarlHonore_2005G.stm',
#  'BillClinton_2007.stm',
#  'SaulGriffith_2009.stm',
#  'SylviaEarle_2009.stm',
#  'DanBuettner_2009X.stm',
#  'DanAriely_2008P.stm',
#  'RobertFull_2005.stm',
#  'PattieMaes_2009.stm',
#  'TarynSimon_2009G.stm',
#  'WadeDavis_2008.stm',
#  'LizDiller_2007P.stm',
#  'DavidPogue_2007.stm',
#  'ClayShirky_2009S.stm',
#  'ChristopherdeCharms_2008.stm',
#  'BenKatchor_2002.stm',
#  'MargaretWertheim_2009.stm',
#  'EveEnsler_2005G.stm',
#  'TimBrown_2008P.stm',
#  'MihalyCsikszentmihalyi_2004.stm',
#  'MarvinMinsky_2003.stm',
#  'PhilipRosedale_2008P.stm',
#  'StephenPalumbi_2010Z.stm',
#  'WilliamKamkwamba_2007G.stm',
#  'JamesGeary_2009G.stm',
#  'BarbaraBlock_2010Z.stm',
#  'JuliaSweeney_2006.stm',
#  'MaeJemison_2002.stm',
#  'NgoziOkonjoIweala_2007.stm',
#  'SteveJurvetson_2007.stm',
#  'KristinaGjerde_2010Z.stm',
#  'SasaVucinic_2005G.stm',
#  'JohannaBlakley_2009X.stm',
#  'DerekSivers_2009I.stm',
#  'ZeFrank_2010G.stm',
#  'SophalEar_2009U.stm',
#  'CarterEmmart_2010.stm',
#  'StefanSagmeister_2004.stm',
#  'PatriciaBurchat_2008.stm',
#  'LaurieSantos_2010G.stm',
#  'DavidByrne_2010.stm',
#  'DavidMacaulay_2002.stm',
#  'ChrisJordan_2008.stm',
#  'EamesDemetrios_2007.stm',
#  'RayZahab_2009.stm',
#  'JamieHeywood_2009P.stm',
#  'AnnaDeavereSmith_2005.stm',
#  'BillGates_2009.stm',
#  'ItayTalgam_2009G.stm',
#  'JuanEnriquez_2003.stm',
#  'LauraTrice_2008.stm',
#  'SimonSinek_2009X.stm',
#  'GeorgeDyson_2003.stm',
#  'LorettaNapoleoni_2009G.stm',
#  'MatthewChilds_2009U.stm',
#  'LarryLessig_2007.stm',
#  'TomShannon_2003.stm',
#  'PeterMolyneux_2010G.stm',
#  'SethBerkley_2010.stm',
#  'DanMeyer_2010X.stm',
#  'SethGodin_2003.stm',
#  'JakeShimabukuro_2010.stm',
#  'NicholasChristakis_2010S.stm',
#  'RickWarren_2006.stm',
#  'NicholasNegroponte_2008.stm',
#  'JamesHowardKunstler_2004.stm',
#  'JanineBenyus_2005.stm',
#  'JamesRandi_2007.stm',
#  'JohnLaGrou_2009.stm',
#  'NathanielKahn_2002.stm',
#  'SirenaHuang_2006.stm',
#  'GeorgeWhitesides_2010.stm',
#  'JamesWatson_2005.stm',
#  'RivesMOCKINGBIRD_2006.stm',
#  'ErnestMadu_2007G.stm',
#  'DeeBoersma_2010Z.stm',
#  'HansRosling_2007.stm',
#  'CarneRoss_2009P.stm',
#  'JosephPine_2004.stm',
#  'NicholasNegroponte_2006.stm',
#  'RobertThurman_2009P.stm',
#  'TodMachover_2008.stm',
#  'TimBrown_2009G.stm',
#  'PaulaScher_2008P.stm',
#  'SuheirHammad_2010W.stm',
#  'ThomMayne_2005.stm',
#  'PaulBennett_2005G.stm',
#  'NaliniNadkarni_2009.stm',
#  'JulianaMachadoFerreira_2010U.stm',
#  'FabianHemmert_2009X.stm',
#  'NellieMcKayTHEDOGSONG_2008.stm',
#  'BillStrickland_2002.stm',
#  'StaceyKramer_2010.stm',
#  'SteveTruglia_2009G.stm',
#  'JoshuaKlein_2008.stm',
#  'NathanMyhrvold_2010.stm',
#  'ErinMcKean_2007.stm',
#  'DanGilbert_2005G.stm',
#  'KirkCitron_2010.stm',
#  'StephenLawler_2007.stm',
#  'PaulRothemund_2008.stm',
#  'FreemanDyson_2003.stm',
#  'PawanSinha_2009I.stm',
#  'JoshSilver_2009G.stm',
#  'EllenGustafson_2010X.stm',
#  'HillelCooperman_2010U.stm',
#  'AlanKay_2007.stm',
#  'BrianCox_2010S.stm',
#  'CatherineMohr_2009.stm',
#  'EinsteinTheParrot_2006.stm',
#  'NicMarks_2010G.stm',
#  'StevenJohnson_2006S.stm',
#  'PhilBorges_2006.stm',
#  'GarrettLisi_2008.stm',
#  'KwabenaBoahen_2007G.stm',
#  'JamieOliver_2010.stm',
#  'MichaelShermer_2006.stm',
#  'DenisDutton_2010.stm',
#  'JaneChen_2009I.stm',
#  'DennisvanEngelsdorp_2008P.stm',
#  'GeverTulley_2007U.stm',
#  'JacquelineNovogratz_2005G.stm',
#  'EOWilson_2007.stm',
#  'DavidCarson_2003.stm',
#  'DennisHong_2009X.stm',
#  'KevinKelly_2009X.stm',
#  'CarolineLavelleFARTHERTHANTHESUN_2005.stm',
#  'ThelmaGolden_2009.stm',
#  'DavidCameron_2010.stm',
#  'TomWujec_2009GU.stm',
#  'TomWujec_2009U.stm',
#  'JonathanZittrain_2009G.stm',
#  'HansRosling_2010X.stm',
#  'UeliGegenschatz_2009.stm',
#  'ShereenElFeki_2009G.stm',
#  'JanineBenyus_2009G.stm',
#  'ShashiTharoor_2009I.stm',
#  'AlSeckel_2004.stm',
#  'ShaffiMather_2009I.stm',
#  'MosheSafdie_2002.stm',
#  'YannArthusBertrand_2009.stm',
#  'MargaretStewart_2010U.stm',
#  'MarkRoth_2010.stm',
#  'GolanLevin_2009.stm',
#  'StefanaBroadbent_2009G.stm',
#  'EmilyLevine_2002.stm',
#  'SamHarris_2010.stm',
#  'StevenJohnson_2003.stm',
#  'AlanRussell_2006.stm',
#  'SheilaPatek_2004.stm',
#  'AllisonHunt_2007.stm',
#  'ShekharKapur_2009I.stm',
#  'TimBernersLee_2009.stm',
#  'AsherHasan_2009I.stm',
#  'DanielLibeskind_2009.stm',
#  'JodyWilliams_2010W.stm',
#  'JessicaJackley_2010G.stm',
#  'BrianCox_2008.stm',
#  'NatashaTsakos_2009.stm',
#  'NuclearDebate_2010.stm',
#  'AdamSavage_2008P.stm',
#  'ShuklaBose_2009I.stm',
#  'JillBolteTaylor_2008.stm',
#  'BrendaLaurel_1998.stm',
#  'CarolinePhillips_2010G.stm',
#  'ArthurBenjamin_2005.stm',
#  'CalebChung_2007P.stm',
#  'Bono_2005.stm',
#  'NicholasNegroponte_1984.stm',
#  'AnilGupta_2009I.stm',
#  'DiannaCohen_2010Z.stm',
#  'PaulCollier_2008.stm',
#  'CarolynPorco_2007.stm',
#  'DanPhillips_2010X.stm',
#  'DerekSivers_2010G.stm',
#  'EmilyOster_2007.stm',
#  'DeanKamen_2007.stm',
#  'DavidPerry_2006.stm',
#  'PaulStamets_2008.stm',
#  'ChristienMeindertsma_2010G.stm',
#  'XDRTB_2008.stm',
#  'AuretvanHeerden_2010G.stm',
#  'MarcKoska_2009G.stm',
#  'TheyMightBeGiants_2007.stm',
#  'ThomasDolbyandRachelleGarniezLAVIEENROSE_2004.stm',
#  'RobertFull_2002.stm',
#  'PeterTyack_2010Z.stm',
#  'CarolynPorco_2009U.stm',
#  'JeremyJackson_2010Z.stm',
#  'KeithSchachtandZachKaplan_2005.stm',
#  'NielsDiffrient_2002a.stm',
#  'BenjaminWallace_2008P.stm',
#  'CharlesLeadbeater_2005G.stm',
#  'OmarAhmad_2010U.stm',
#  'LouiseFresco_2009.stm',
#  'CaryFowler_2009G.stm',
#  'FrederickBalagadde_2010U.stm',
#  'MichelleObama_2009P.stm',
#  'TomRielly_2006.stm',
#  'AimeeMullins_1998.stm',
#  'KevinKelly_2005.stm',
#  'BruceMcCall_2008P.stm',
#  'HectorRuiz_2007G.stm',
#  'DanCobley_2010G.stm',
#  'RonEglash_2007G2.stm',
#  'JaredDiamond_2003.stm',
#  'PranavMistry_2009I.stm',
#  'BrewsterKahle_2007P.stm',
#  'StevenPinker_2007.stm',
#  'BenDunlap_2007.stm',
#  'MurrayGellMann_2007.stm',
#  'NickSears_2007.stm',
#  'StefanoMancuso_2010G.stm',
#  'DavidDeutsch_2005G.stm',
#  'Halla_Tomasdottir_2010W.stm',
#  'DimitarSasselov_2010G.stm',
#  'MazJobrani_2010G.stm',
#  'VusiMahlaselaSONGOFMAMA_2007G.stm',
#  'JohnWooden_2001.stm',
#  'ChristopherPoole_2010.stm',
#  'FrankGehry_2002.stm',
#  'DavidKelley_2002.stm',
#  'EricTopol_2009P.stm',
#  'StevenLevitt_2005G.stm',
#  'RickSmolan_2007P.stm',
#  'ErikHersman_2009U.stm',
#  'JohnLloyd_2009G.stm',
#  'AlisonJackson_2005G.stm',
#  'RichardDawkins_2002.stm',
#  'BeverlyJoubertandDereckJoubert_2010W.stm',
#  'SendhilMullainathan_2009I.stm',
#  'SethGodin_2009.stm',
#  'WilliamLi_2010.stm',
#  'RobinChase_2007.stm',
#  'PeterWard_2008.stm',
#  'BillyGraham_1998.stm',
#  'HarshaBhogle_2009I.stm',
#  'DavidGallo_2007.stm',
#  'NaomiKlein_2010W.stm',
#  'PWSinger_2009.stm',
#  'BarrySchwartz_2010S.stm',
#  'LeeHotz_2010G.stm',
#  'DeanKamen_2002.stm',
#  'JohnHodgman_2008.stm',
#  'CharlesFleischer_2005.stm',
#  'AndersYnnerman_2010X.stm',
#  'StevenPinker_2005G.stm',
#  'JulianAssange_2010G.stm',
#  'StephenWolfram_2010.stm',
#  'JosephNye_2010G.stm',
#  'MatthieuRicard_2004.stm',
#  'NinaJablonski_2009.stm',
#  'JenniferLin_2004.stm',
#  'JuanEnriquez_2007S.stm',
#  'ChrisAnderson_2010G.stm',
#  'BillStone_2007.stm',
#  'IsabelAllende_2007.stm',
#  'BonnieBassler_2009.stm',
#  'StevenPinker_2003.stm',
#  'MarcelDicke_2010G.stm',
#  'SherylWuDunn_2010G.stm',
#  'SugataMitra_2007P.stm',
#  'SeanGourley_2009U.stm',
#  'DavidAgus_2009P.stm',
#  'GeorgeDyson_2002.stm',
#  'MikedeGruy_2010Z.stm',
#  'RyanLobo_2009I.stm']

# %%
#### All speakers are 

All_Speakers_Word_List = []
#Speaker_Individual_Files = []
for TALK in TALK_IDs:
    pathname = directory + '/' + TALK
    #pathname = "/Users/test/Desktop/Audio Vox Datasets and References/TEDLIUM_release1/train/stm/" + TALK
    with open(pathname, 'r') as f:
        lines = f.readlines()
        for L in lines:
            Line = L.strip()
            #print(Line)
            
            Line = Line.split('>')[1]
            #print(Line)

            # split line into words
            Words_in_Line = Line.split(' ')
            # remove first element (which is always an empty string)
            Words_in_Line = Words_in_Line[1:]
            if Words_in_Line[0] == 'ignore_time_segment_in_scoring':
                pass
            else:
                for w in Words_in_Line:
                    W = w.split('(')[0]
                    
                    ## Checks for an empty string (they are "falsey")
                    if not W:
                        pass
                    else:
                        
                        ## Checks to remove non-word sounds (coughs, bumps, etc)
                        if W[0] == '<' or W[0] == '{':
                            pass
                        else:
                            All_Speakers_Word_List.append(W)

# %%
print(len(All_Speakers_Word_List))
#random.shuffle(All_Speakers_Word_List)

#All_Speakers_Word_List = All_Speakers_Word_List[:265000]
#print(len(All_Speakers_Word_List))
# Out:
# 582721

# %%
import pickle
Master_Dict = pickle.load(open("Master_Dict.pkl", "rb"))

# %%
Master_Dict['TEDLIUM Corpus'] = All_Speakers_Word_List

# %%
word_count = Counter(All_Speakers_Word_List)
word_count = sorted(word_count.items(), key=lambda xy: xy[1], reverse=True)
words_id = np.asarray(word_count)[:,0]
freq_of_word_counts = np.asarray(word_count)[:,1]

# %%
len(word_count)
# Out:
# 15630

# %%
rank_list = []
freq_list = []
for i in range(len(word_count)):
    rank_list.append(i)
    freq_list.append(word_count[i][1])
    
f,ax = plt.subplots()
ax.scatter(rank_list,freq_list)
ax.set_xlabel("Rank")
ax.set_ylabel("Frequency")
ax.set_xscale("Log")
ax.set_yscale("Log")
ax.set_xlim(1,25000)
# Out:
# (1, 25000)

# %%
word_count
# Out:
# [('the', 13383),
#  ('and', 9436),
#  ('to', 7557),
#  ('of', 6891),
#  ('a', 6538),
#  ('that', 5330),
#  ('in', 4673),
#  ('i', 4659),
#  ('is', 4492),
#  ('you', 4229),
#  ('we', 3862),
#  ('this', 3570),
#  ('it', 3222),
#  ('so', 2830),
#  ('was', 1964),
#  ('have', 1837),
#  ('are', 1716),
#  ('they', 1716),
#  ('for', 1694),
#  ('what', 1663),
#  ('but', 1663),
#  ('on', 1582),
#  ('with', 1427),
#  ('one', 1415),
#  ("it's", 1391),
#  ('about', 1390),
#  ('can', 1286),
#  ('as', 1227),
#  ('all', 1199),
#  ('at', 1158),
#  ('be', 1146),
#  ('do', 1145),
#  ('not', 1093),
#  ('if', 1058),
#  ('now', 1015),
#  ('there', 977),
#  ('from', 964),
#  ('like', 963),
#  ('my', 961),
#  ('people', 958),
#  ('these', 926),
#  ('he', 924),
#  ('know', 895),
#  ('when', 892),
#  ("'s", 889),
#  ('just', 843),
#  ('out', 834),
#  ('very', 833),
#  ('an', 793),
#  ('here', 788),
#  ('because', 781),
#  ('see', 774),
#  ('think', 769),
#  ('our', 746),
#  ('or', 726),
#  ('how', 725),
#  ('up', 721),
#  ('me', 711),
#  ('had', 704),
#  ('going', 700),
#  ('by', 698),
#  ('which', 694),
#  ('really', 691),
#  ('then', 683),
#  ('them', 653),
#  ('would', 630),
#  ('more', 614),
#  ("that's", 609),
#  ('get', 585),
#  ('two', 585),
#  ('your', 574),
#  ('were', 570),
#  ('some', 562),
#  ("i'm", 549),
#  ('who', 545),
#  ('actually', 545),
#  ('world', 529),
#  ('time', 528),
#  ('things', 527),
#  ('has', 525),
#  ('their', 522),
#  ('way', 501),
#  ("don't", 494),
#  ('us', 487),
#  ('years', 480),
#  ('go', 478),
#  ('will', 472),
#  ('into', 467),
#  ("we're", 465),
#  ('well', 462),
#  ('want', 460),
#  ('other', 442),
#  ('could', 440),
#  ('said', 430),
#  ('make', 427),
#  ('no', 419),
#  ('first', 417),
#  ('where', 416),
#  ('little', 399),
#  ('look', 392),
#  ('those', 390),
#  ('been', 389),
#  ('thing', 382),
#  ('got', 378),
#  ('also', 378),
#  ('something', 373),
#  ('kind', 372),
#  ('say', 371),
#  ('new', 360),
#  ('much', 355),
#  ('right', 343),
#  ('three', 343),
#  ('back', 337),
#  ('most', 330),
#  ('work', 323),
#  ('many', 323),
#  ('life', 318),
#  ('than', 318),
#  ("there's", 311),
#  ('she', 306),
#  ('over', 305),
#  ('why', 301),
#  ('take', 300),
#  ('hundred', 299),
#  ('lot', 297),
#  ('down', 297),
#  ("you're", 295),
#  ('need', 292),
#  ('only', 289),
#  ('his', 288),
#  ('did', 285),
#  ('around', 282),
#  ('five', 281),
#  ('good', 277),
#  ('put', 274),
#  ("they're", 271),
#  ('thousand', 271),
#  ('come', 253),
#  ('even', 247),
#  ("we've", 243),
#  ('let', 238),
#  ('same', 237),
#  ('doing', 230),
#  ('called', 224),
#  ('through', 223),
#  ('last', 222),
#  ('talk', 219),
#  ('great', 219),
#  ('another', 218),
#  ('being', 215),
#  ('different', 215),
#  ('tell', 211),
#  ('use', 211),
#  ('idea', 210),
#  ('year', 210),
#  ('twenty', 209),
#  ('every', 207),
#  ("i've", 204),
#  ('sort', 203),
#  ('made', 203),
#  ('after', 202),
#  ('went', 201),
#  ('thought', 198),
#  ('point', 195),
#  ('day', 190),
#  ('fact', 190),
#  ('her', 190),
#  ('came', 189),
#  ('start', 187),
#  ('four', 185),
#  ('show', 184),
#  ('find', 183),
#  ('important', 182),
#  ('course', 178),
#  ('any', 176),
#  ('started', 174),
#  ('big', 171),
#  ('ago', 171),
#  ('today', 170),
#  ('change', 170),
#  ("didn't", 169),
#  ('long', 167),
#  ('part', 167),
#  ('again', 166),
#  ('human', 166),
#  ('problem', 165),
#  ('off', 161),
#  ('own', 160),
#  ('few', 158),
#  ('ten', 156),
#  ('never', 156),
#  ('next', 156),
#  ('before', 156),
#  ('does', 155),
#  ('system', 155),
#  ('each', 155),
#  ('story', 154),
#  ('whole', 154),
#  ('should', 154),
#  ('try', 152),
#  ('percent', 151),
#  ('mean', 150),
#  ("can't", 150),
#  ('used', 147),
#  ('brain', 146),
#  ('give', 145),
#  ('might', 145),
#  ('technology', 145),
#  ('its', 143),
#  ("what's", 142),
#  ('better', 141),
#  ('him', 140),
#  ('love', 140),
#  ('second', 139),
#  ('able', 139),
#  ('believe', 139),
#  ('million', 139),
#  ('bit', 138),
#  ('place', 138),
#  ('design', 138),
#  ('real', 137),
#  ('together', 136),
#  ('maybe', 134),
#  ('wanted', 134),
#  ('still', 134),
#  ('question', 134),
#  ('too', 132),
#  ('looking', 130),
#  ('took', 129),
#  ('between', 128),
#  ('live', 128),
#  ('old', 127),
#  ('may', 127),
#  ('end', 127),
#  ("i'd", 127),
#  ('call', 126),
#  ('trying', 124),
#  ('six', 123),
#  ('done', 123),
#  ("doesn't", 122),
#  ('thirty', 122),
#  ('sense', 121),
#  ('stuff', 121),
#  ('left', 119),
#  ('high', 119),
#  ('water', 118),
#  ('away', 116),
#  ('example', 116),
#  ('understand', 113),
#  ('talking', 113),
#  ('always', 112),
#  ('quite', 112),
#  ('person', 111),
#  ('thinking', 111),
#  ('working', 111),
#  ('become', 111),
#  ('found', 110),
#  ('number', 109),
#  ('kids', 109),
#  ('feel', 107),
#  ('getting', 107),
#  ('women', 106),
#  ('building', 105),
#  ('side', 103),
#  ('city', 103),
#  ('power', 103),
#  ('comes', 102),
#  ('times', 102),
#  ('data', 102),
#  ('create', 101),
#  ('help', 101),
#  ('enough', 101),
#  ('ideas', 101),
#  ('money', 100),
#  ('man', 100),
#  ('fifty', 100),
#  ('everything', 100),
#  ('food', 99),
#  ('means', 99),
#  ('school', 99),
#  ('small', 99),
#  ('earth', 99),
#  ('happened', 98),
#  ('pretty', 98),
#  ('probably', 98),
#  ('says', 98),
#  ('energy', 98),
#  ('having', 96),
#  ('interesting', 95),
#  ('experience', 94),
#  ('seven', 94),
#  ('coming', 93),
#  ('once', 93),
#  ('goes', 93),
#  ('book', 93),
#  ('country', 92),
#  ('saying', 92),
#  ('across', 91),
#  ('days', 91),
#  ('space', 91),
#  ('best', 91),
#  ('dollars', 90),
#  ("i'll", 90),
#  ('happens', 90),
#  ('hand', 90),
#  ('basically', 89),
#  ('move', 89),
#  ('eight', 89),
#  ("you've", 88),
#  ('children', 88),
#  ('ever', 88),
#  ('half', 88),
#  ('mind', 87),
#  ('light', 87),
#  ('project', 86),
#  ('often', 85),
#  ('far', 85),
#  ('computer', 85),
#  ('seen', 85),
#  ('saw', 85),
#  ('making', 84),
#  ('am', 84),
#  ('build', 84),
#  ('ok', 84),
#  ('africa', 83),
#  ('future', 82),
#  ('asked', 82),
#  ('picture', 82),
#  ('told', 82),
#  ('simple', 82),
#  ('forty', 82),
#  ('such', 81),
#  ('less', 81),
#  ('process', 81),
#  ('problems', 81),
#  ('both', 80),
#  ('room', 80),
#  ('guy', 80),
#  ('using', 80),
#  ('science', 80),
#  ('happen', 80),
#  ('planet', 80),
#  ('bad', 79),
#  ('sure', 79),
#  ('play', 79),
#  ('places', 79),
#  ('reason', 79),
#  ('business', 79),
#  ('set', 78),
#  ('within', 78),
#  ('looks', 77),
#  ('anything', 77),
#  ('without', 77),
#  ('body', 77),
#  ('couple', 77),
#  ('nine', 76),
#  ('built', 76),
#  ('true', 76),
#  ('ask', 76),
#  ('billion', 75),
#  ('though', 75),
#  ('makes', 75),
#  ('moment', 75),
#  ('health', 74),
#  ('case', 74),
#  ('war', 73),
#  ('everybody', 73),
#  ('since', 73),
#  ('social', 73),
#  ('while', 73),
#  ('yet', 73),
#  ('bring', 73),
#  ('hard', 73),
#  ('nothing', 73),
#  ('ourselves', 72),
#  ('later', 72),
#  ('top', 72),
#  ('remember', 72),
#  ('looked', 72),
#  ('living', 71),
#  ('information', 71),
#  ('turns', 71),
#  ('must', 71),
#  ('nature', 70),
#  ('heard', 70),
#  ('amazing', 70),
#  ('keep', 70),
#  ('s', 69),
#  ('home', 69),
#  ('along', 69),
#  ('ways', 69),
#  ('kinds', 68),
#  ('group', 68),
#  ('young', 68),
#  ('line', 68),
#  ('order', 67),
#  ('whether', 67),
#  ('okay', 67),
#  ('mother', 67),
#  ('god', 67),
#  ('completely', 67),
#  ("'t", 67),
#  ('company', 67),
#  ('child', 66),
#  ('middle', 66),
#  ('music', 66),
#  ('happening', 66),
#  ('learn', 66),
#  ('large', 66),
#  ('model', 66),
#  ('figure', 66),
#  ('game', 66),
#  ('beginning', 65),
#  ('yes', 65),
#  ('particular', 65),
#  ('hope', 65),
#  ('ones', 65),
#  ('fifteen', 65),
#  ('works', 65),
#  ('piece', 64),
#  ('thank', 64),
#  ('community', 64),
#  ('family', 64),
#  ('area', 64),
#  ('read', 64),
#  ('already', 64),
#  ('possible', 64),
#  ('third', 64),
#  ('else', 64),
#  ('someone', 64),
#  ('imagine', 63),
#  ('animals', 63),
#  ('natural', 63),
#  ('inside', 63),
#  ('heart', 63),
#  ('somebody', 62),
#  ('single', 62),
#  ('stories', 62),
#  ('words', 62),
#  ('history', 61),
#  ('age', 61),
#  ('wrong', 61),
#  ('species', 61),
#  ('form', 61),
#  ('state', 61),
#  ('u', 60),
#  ('ted', 60),
#  ('sound', 60),
#  ('states', 60),
#  ('car', 60),
#  ('taken', 59),
#  ('job', 59),
#  ('finally', 59),
#  ('oil', 59),
#  ('decided', 59),
#  ('cells', 59),
#  ('myself', 59),
#  ('learned', 59),
#  ('under', 59),
#  ("isn't", 59),
#  ('guys', 59),
#  ('entire', 58),
#  ('public', 58),
#  ('house', 58),
#  ('knew', 58),
#  ('head', 58),
#  ('happy', 58),
#  ('answer', 58),
#  ('amount', 58),
#  ('matter', 57),
#  ('view', 57),
#  ('open', 57),
#  ('tried', 57),
#  ('moving', 57),
#  ('face', 57),
#  ('self', 57),
#  ('video', 57),
#  ('gone', 57),
#  ('stop', 57),
#  ('universe', 57),
#  ('oh', 57),
#  ('lots', 57),
#  ('minutes', 56),
#  ('exactly', 56),
#  ('seeing', 56),
#  ('level', 56),
#  ('hours', 56),
#  ("you'll", 56),
#  ('free', 56),
#  ('men', 56),
#  ('months', 56),
#  ('lives', 55),
#  ('american', 55),
#  ('run', 55),
#  ('students', 55),
#  ('word', 55),
#  ('government', 55),
#  ('beautiful', 55),
#  ('sometimes', 55),
#  ('gets', 54),
#  ('research', 54),
#  ('environment', 54),
#  ('turn', 54),
#  ('interested', 53),
#  ('based', 53),
#  ('cost', 53),
#  ('perhaps', 53),
#  ('worked', 53),
#  ('past', 53),
#  ('york', 53),
#  ('gave', 53),
#  ('least', 53),
#  ('culture', 52),
#  ('countries', 52),
#  ("wasn't", 52),
#  ('wonderful', 52),
#  ('name', 51),
#  ('care', 51),
#  ("they've", 51),
#  ('until', 51),
#  ('low', 51),
#  ('front', 51),
#  ('seems', 51),
#  ('size', 50),
#  ('difference', 50),
#  ('feet', 50),
#  ('began', 50),
#  ('taking', 50),
#  ('felt', 50),
#  ('education', 50),
#  ('created', 50),
#  ('green', 49),
#  ('machine', 49),
#  ('america', 49),
#  ('ninety', 49),
#  ('news', 49),
#  ('talked', 49),
#  ('almost', 49),
#  ('theory', 49),
#  ('during', 49),
#  ('sitting', 49),
#  ('friend', 49),
#  ('market', 49),
#  ('realized', 48),
#  ('parts', 48),
#  ('society', 48),
#  ('scale', 48),
#  ('powerful', 48),
#  ('everyone', 48),
#  ('leave', 48),
#  ('itself', 48),
#  ("we'll", 48),
#  ('certain', 48),
#  ('huge', 48),
#  ('united', 48),
#  ('won', 48),
#  ('global', 48),
#  ('share', 47),
#  ('stand', 47),
#  ('early', 47),
#  ('century', 47),
#  ('study', 47),
#  ('walk', 47),
#  ('south', 47),
#  ('internet', 47),
#  ('deep', 47),
#  ('write', 47),
#  ('given', 47),
#  ('longer', 47),
#  ('whatever', 47),
#  ('wrote', 47),
#  ('image', 46),
#  ('brought', 46),
#  ('dna', 46),
#  ('sixty', 46),
#  ('control', 46),
#  ('rules', 46),
#  ('outside', 46),
#  ('rest', 46),
#  ('morning', 46),
#  ("she's", 45),
#  ('art', 45),
#  ('instead', 45),
#  ('force', 45),
#  ('nice', 45),
#  ('night', 45),
#  ('needs', 45),
#  ('woman', 45),
#  ('father', 45),
#  ('easy', 44),
#  ('watch', 44),
#  ('needed', 44),
#  ('deal', 44),
#  ('terms', 44),
#  ('rather', 44),
#  ('miles', 44),
#  ('media', 44),
#  ('air', 44),
#  ('systems', 44),
#  ('common', 44),
#  ('per', 44),
#  ('seventy', 44),
#  ('bottom', 44),
#  ('eighty', 44),
#  ('spent', 44),
#  ('language', 44),
#  ('starting', 44),
#  ('center', 43),
#  ('shows', 43),
#  ('test', 43),
#  ('cities', 43),
#  ('simply', 43),
#  ('zero', 43),
#  ('india', 43),
#  ('opportunity', 43),
#  ('close', 43),
#  ('turned', 43),
#  ('themselves', 43),
#  ('red', 43),
#  ('became', 42),
#  ('buy', 42),
#  ('approach', 42),
#  ('land', 42),
#  ('local', 42),
#  ('ocean', 42),
#  ('device', 42),
#  ('eyes', 42),
#  ('technologies', 42),
#  ('stage', 41),
#  ('china', 41),
#  ('knows', 41),
#  ('yeah', 41),
#  ('evolution', 41),
#  ('against', 41),
#  ('met', 41),
#  ('surface', 41),
#  ('books', 40),
#  ('hear', 40),
#  ('focus', 40),
#  ('showed', 40),
#  ('designed', 40),
#  ('designers', 40),
#  ('short', 40),
#  ('known', 40),
#  ('field', 40),
#  ('quickly', 40),
#  ('yourself', 40),
#  ("couldn't", 40),
#  ('either', 40),
#  ('white', 40),
#  ('incredible', 40),
#  ('fun', 39),
#  ('film', 39),
#  ('friends', 39),
#  ('companies', 39),
#  ('population', 39),
#  ('reasons', 39),
#  ('nobody', 39),
#  ('full', 39),
#  ('experiment', 39),
#  ('animal', 39),
#  ('team', 38),
#  ('feeling', 38),
#  ('phone', 38),
#  ('recently', 38),
#  ('learning', 38),
#  ('cannot', 38),
#  ('games', 38),
#  ('structure', 38),
#  ('growing', 38),
#  ('asking', 38),
#  ('week', 38),
#  ('explain', 38),
#  ('disease', 38),
#  ('projects', 38),
#  ('changed', 38),
#  ('map', 38),
#  ('teach', 38),
#  ('twelve', 38),
#  ('beyond', 37),
#  ('numbers', 37),
#  ('economy', 37),
#  ('step', 37),
#  ('tools', 37),
#  ('resources', 37),
#  ('camera', 37),
#  ('exciting', 37),
#  ('ability', 37),
#  ('others', 37),
#  ('behavior', 37),
#  ('lost', 37),
#  ('seem', 37),
#  ('industry', 37),
#  ('showing', 37),
#  ('hundreds', 37),
#  ('running', 37),
#  ('certainly', 37),
#  ('growth', 36),
#  ('grow', 36),
#  ('spend', 36),
#  ('begin', 36),
#  ('becomes', 36),
#  ('lose', 36),
#  ('law', 36),
#  ('cancer', 36),
#  ('complex', 36),
#  ('excited', 36),
#  ('difficult', 36),
#  ('somehow', 35),
#  ('nineteen', 35),
#  ('lead', 35),
#  ('sun', 35),
#  ('break', 35),
#  ('allow', 35),
#  ('modern', 35),
#  ('meet', 35),
#  ('effect', 35),
#  ('re', 35),
#  ('chance', 35),
#  ('questions', 35),
#  ('network', 35),
#  ('dark', 35),
#  ('speak', 35),
#  ('economic', 35),
#  ('developed', 34),
#  ('thousands', 34),
#  ('sea', 34),
#  ('parents', 34),
#  ('materials', 34),
#  ('walking', 34),
#  ('movie', 34),
#  ('takes', 33),
#  ('cell', 33),
#  ('suddenly', 33),
#  ('town', 33),
#  ('eat', 33),
#  ('fall', 33),
#  ('higher', 33),
#  ('putting', 33),
#  ('non', 33),
#  ('lived', 33),
#  ('mars', 33),
#  ('challenge', 33),
#  ('slide', 33),
#  ("haven't", 33),
#  ('shape', 33),
#  ('university', 33),
#  ('solar', 33),
#  ('realize', 33),
#  ('development', 33),
#  ('changes', 33),
#  ('speed', 33),
#  ('mass', 33),
#  ('fast', 33),
#  ('present', 32),
#  ('listen', 32),
#  ('audience', 32),
#  ('cool', 32),
#  ('object', 32),
#  ('generation', 32),
#  ('involved', 32),
#  ('behind', 32),
#  ('girls', 32),
#  ('indeed', 32),
#  ('areas', 32),
#  ('program', 32),
#  ('reading', 32),
#  ('playing', 32),
#  ('pattern', 32),
#  ('series', 32),
#  ('normal', 32),
#  ('relationship', 32),
#  ('telling', 32),
#  ('pictures', 32),
#  ('digital', 32),
#  ('discovered', 31),
#  ('supposed', 31),
#  ('anyway', 31),
#  ('potential', 31),
#  ('creating', 31),
#  ('named', 31),
#  ('product', 31),
#  ('wish', 31),
#  ('happiness', 31),
#  ('key', 31),
#  ('site', 31),
#  ('web', 31),
#  ('nuclear', 31),
#  ('climate', 31),
#  ('died', 31),
#  ('measure', 31),
#  ('millions', 31),
#  ('english', 31),
#  ('black', 31),
#  ('pay', 31),
#  ('fish', 30),
#  ('ground', 30),
#  ('lab', 30),
#  ('eighteen', 30),
#  ('die', 30),
#  ('eleven', 30),
#  ('north', 30),
#  ('quality', 30),
#  ('wall', 30),
#  ('computers', 30),
#  ('east', 30),
#  ('born', 30),
#  ('solution', 30),
#  ('developing', 30),
#  ('teacher', 30),
#  ('notice', 30),
#  ('towards', 30),
#  ('ended', 30),
#  ('major', 30),
#  ('trees', 30),
#  ('led', 30),
#  ('blue', 29),
#  ('type', 29),
#  ('weeks', 29),
#  ('similar', 29),
#  ('although', 29),
#  ('grew', 29),
#  ('hit', 29),
#  ('square', 29),
#  ('value', 29),
#  ('watching', 29),
#  ('hold', 29),
#  ('wonder', 29),
#  ('d', 29),
#  ('changing', 29),
#  ('humans', 29),
#  ('further', 29),
#  ('baby', 29),
#  ('reach', 29),
#  ('sit', 29),
#  ('hands', 29),
#  ('values', 29),
#  ('develop', 29),
#  ('basic', 29),
#  ('issue', 29),
#  ('national', 29),
#  ('complicated', 28),
#  ('ice', 28),
#  ('creative', 28),
#  ("wouldn't", 28),
#  ('month', 28),
#  ('spread', 28),
#  ('moved', 28),
#  ('version', 28),
#  ('schools', 28),
#  ('greatest', 28),
#  ('soon', 28),
#  ('paper', 28),
#  ('chinese', 28),
#  ('special', 28),
#  ('office', 28),
#  ('meant', 27),
#  ('pieces', 27),
#  ('fantastic', 27),
#  ('western', 27),
#  ('period', 27),
#  ('machines', 27),
#  ('software', 27),
#  ('giving', 27),
#  ('clear', 27),
#  ('class', 27),
#  ('truly', 27),
#  ('images', 27),
#  ('training', 27),
#  ('organization', 27),
#  ('main', 27),
#  ("they'll", 27),
#  ('largest', 27),
#  ('scientists', 27),
#  ('song', 27),
#  ('security', 27),
#  ('above', 27),
#  ('doctor', 27),
#  ('situation', 27),
#  ('result', 27),
#  ('several', 27),
#  ('available', 27),
#  ('earlier', 27),
#  ('goal', 27),
#  ('movement', 27),
#  ('innovation', 27),
#  ('average', 27),
#  ('continue', 26),
#  ('interest', 26),
#  ('dollar', 26),
#  ('moon', 26),
#  ('organisms', 26),
#  ('material', 26),
#  ('anybody', 26),
#  ('tree', 26),
#  ('remarkable', 26),
#  ('table', 26),
#  ('stay', 26),
#  ('support', 26),
#  ('girl', 26),
#  ('reality', 26),
#  ('follow', 26),
#  ('buildings', 26),
#  ('village', 26),
#  ('beauty', 26),
#  ("we'd", 26),
#  ('vision', 26),
#  ('literally', 26),
#  ('solve', 26),
#  ('revolution', 26),
#  ('boy', 26),
#  ("you'd", 26),
#  ('produce', 26),
#  ('impact', 26),
#  ('message', 26),
#  ('robots', 26),
#  ('cut', 26),
#  ('forms', 26),
#  ('truth', 26),
#  ('fly', 26),
#  ('west', 26),
#  ('individual', 25),
#  ('written', 25),
#  ('wants', 25),
#  ('fundamental', 25),
#  ('solutions', 25),
#  ('allowed', 25),
#  ('total', 25),
#  ('physical', 25),
#  ('worst', 25),
#  ('blood', 25),
#  ('fine', 25),
#  ('poor', 25),
#  ('bought', 25),
#  ('shown', 25),
#  ('stars', 25),
#  ('rate', 25),
#  ('sounds', 25),
#  ('journey', 25),
#  ('gives', 25),
#  ('street', 25),
#  ('familiar', 25),
#  ('sent', 25),
#  ('especially', 25),
#  ('personal', 25),
#  ('meaning', 25),
#  ('google', 25),
#  ('general', 25),
#  ('figured', 25),
#  ('kept', 25),
#  ('access', 25),
#  ('rich', 24),
#  ('objects', 24),
#  ('fourth', 24),
#  ('student', 24),
#  ('hiv', 24),
#  ('examples', 24),
#  ('conditions', 24),
#  ('successful', 24),
#  ('extremely', 24),
#  ('guess', 24),
#  ('robot', 24),
#  ('list', 24),
#  ('among', 24),
#  ('allows', 24),
#  ('reduce', 24),
#  ('term', 24),
#  ('add', 24),
#  ('biology', 24),
#  ('carbon', 24),
#  ('evolved', 24),
#  ('obviously', 24),
#  ('pick', 24),
#  ('bunch', 24),
#  ('act', 24),
#  ('worth', 24),
#  ('points', 24),
#  ('death', 24),
#  ('touch', 24),
#  ('direction', 24),
#  ('starts', 24),
#  ('final', 24),
#  ('museum', 24),
#  ('train', 24),
#  ('extraordinary', 24),
#  ('college', 24),
#  ('lines', 24),
#  ('floor', 23),
#  ('flying', 23),
#  ('teaching', 23),
#  ('studies', 23),
#  ('standing', 23),
#  ('lower', 23),
#  ('moral', 23),
#  ('teachers', 23),
#  ('traditional', 23),
#  ('fear', 23),
#  ('online', 23),
#  ('critical', 23),
#  ('character', 23),
#  ...]

# %% [markdown]
# # MLE

# %%
import numpy as np
from scipy.optimize import minimize
from scipy.special import zeta
import mpmath as mpm

def wfd_lin(x):
    '''In: x...list with floats representing data...size of all the words
       Out: k, P(k)...how many words with length k
            array is only constructed for those k-values for which Pk > 0!!!
    '''
    x.sort()
    k = []
    P_k = []
    count_temp = 0
    total = float(len(x))

    for i in np.arange(len(x)):
        if x[i] != count_temp:
            k += [float(x[i])]
            P_k += [float(1)]
            count_temp = x[i]
        else:
            P_k[-1] += 1.0
    P_k = np.array(P_k)/total
    return np.array(k),P_k
    
def wfd_histo(x):
    '''In: x...list with floats representing data...size of all the words
       Out: k, N(k)...how many words with length k
            array is only constructed for those k-values for which Pk > 0!!!
    '''
    x.sort()
    k = []
    N_k = []
    count_temp = 0
    N = float(len(x))
    i = 0
    while i < N:
        if x[i] != count_temp:
            k += [float(x[i])]
            N_k += [float(1)]
            count_temp = x[i]
        else:
            N_k[-1] += 1.0
        i += 1
    return np.array(k),np.array(N_k)

    
## zeta function
def zeta_minmax(gamma,kmin,kmax):
    '''kmax == None means kmax --> infty
    '''
#     gamma = gamma[0]
    if gamma <= 1.0:
        if kmax == None:
            print('ERROR: Series does not converge!!!')
            C = 0
        else:
            mpm.dps=25
#             print(gamma,kmin,kmax,'huhu')
            C = (float(mpm.sumem(lambda k: k**(-gamma),[kmin,kmax])))
    else:
        # print(kmax)
        # print(type(kmax))
        # print(kmax==None)
        # print('')
        if isinstance(kmax,(list,np.ndarray)):
            C = zeta(gamma,kmin)-zeta(gamma,kmax)
        elif kmax == None:
            C = zeta(gamma,kmin)
        else:
            C = zeta(gamma,kmin)-zeta(gamma,kmax)
        # print(C)
    return C
    
def zeta_minmax_cont(gamma,kmin,kmax):
    '''kmax == None means kmax --> infty
    '''
    if kmax==None:
        if gamma > 1.0:
            C = 1.0/(gamma-1)*(kmin**(1-gamma))
        else:
            C = -1#1.0/(gamma-1)*(kmin**(1-gamma) - kmax**(1-gamma))
            print('Error')
    else:
        C = 1.0/(gamma-1)*(kmin**(1-gamma) - kmax**(1-gamma))
    return C

## Leastsquares
def leastsquare(x,y):
    '''least square for y = a0 +a1*x
    '''
    a_0 = (sum(y)*sum(x*x) - sum(x)*sum(x*y))/(len(x)*sum(x*x) - (sum(x))**2.0)
    a_1 = (len(x)*sum(x*y) - sum(x)*sum(y))/(len(x)*sum(x*x) - (sum(x))**2.0)
    return a_0,a_1
    
## Filter functions
def filter_xy(x,y,xmin,xmax,ymin,ymax):
    '''filter where P(k) = 0 when bin in histogram still empty and y = P_k < kmin
    '''
    ind_del_ymin = np.where(y<ymin)[0]
    ind_del_ymax = np.where(y>ymax)[0]
    ind_del_y = np.append(ind_del_ymin,ind_del_ymax)
    
    if xmin != None:
        ind_del_xmin = np.where(x<xmin)[0]
    else:
        ind_del_xmin = []
    if xmax != None:
        ind_del_xmax = np.where(x>xmax)[0]
    else:
        ind_del_xmax = []
    ind_del_x = np.append(ind_del_xmin,ind_del_xmax)
    
    ind_del = np.append(ind_del_y,ind_del_x)
    x_f = np.delete(x,ind_del) 
    y_f = np.delete(y,ind_del)
    return x_f,y_f

def filter_x(x,xmin,xmax):
    '''filter where P(k) = 0 when bin in histogram still empty and y = P_k < kmin
       if xmin or xmax = None it means that it does not exist
    '''
    if xmin != None:
        ind_del_xmin = np.where(x<xmin)[0]
    else:
        ind_del_xmin = []
    if xmax != None:
        ind_del_xmax = np.where(x>xmax)[0]
    else:
        ind_del_xmax = []
    ind_del = np.append(ind_del_xmin,ind_del_xmax)
    
    x_f = np.delete(x,ind_del) 
    return x_f
    


## 2 powerlaws: pk = c*k**(-gamma1) if k<= km, c*km**(gamma2-gamm1)*k**(-gamma2) if k >= km
# faktor fuer k>=km ergibt sich durch anschlussbedingung

def pdf_2exp_disc(x,kmin,kmax,gamma1,gamma2,km):
    '''returns discrete power law with cutoff kmin,kmax...including kmax as last element
       therefore kmax+1 in argument. 
    '''
    if kmax == None:
        C = 1.0/(zeta_minmax(gamma1,kmin,km+1) + km**(gamma2-gamma1)*zeta_minmax(gamma2,km+1,kmax) )
    else:
        C = 1.0/(zeta_minmax(gamma1,kmin,km+1) + km**(gamma2-gamma1)*zeta_minmax(gamma2,km+1,kmax+1) )
    pk = C*((x<=km)*x**(-gamma1) + (x>km)*km**(gamma2-gamma1)*x**(-gamma2))
    return pk
    
def cdf_2exp_disc(x,kmin,kmax,gamma1,gamma2,km):
    '''returns discrete power law with cutoff kmin,kmax...including kmax as last element
       therefore kmax+1 in argument. 
    '''
    zeta_km = zeta_minmax(gamma1,kmin,km+1)
    if kmax == None:
        C = 1.0/(zeta_minmax(gamma1,kmin,km+1) + km**(gamma2-gamma1)*zeta_minmax(gamma2,km+1,kmax) )
    else:
        C = 1.0/(zeta_minmax(gamma1,kmin,km+1) + km**(gamma2-gamma1)*zeta_minmax(gamma2,km+1,kmax+1) )
    Fk = C*((x<=km)*zeta_minmax(gamma1,kmin,x+1) + (x>km)*(zeta_km + km**(gamma2-gamma1)*zeta_minmax(gamma2,km+1,x+1)))
    return Fk


## fit 3 parameters, gamma1 as well
def mle_disc_minmax_optimize_2expzipf_3par(x,kmin,kmax,gamma1_0,gamma2_0,km_0,method = 'Nelder-Mead'):
    N = float(len(x)) #types
    M = float(sum(x)) #tokens
    x = np.sort(x)[::-1]
    rlog = np.log(np.arange(N)+1)
    
    D0 = sum((x/M)*rlog)
    # result = fmin(func_mle_disc_2expzipf_2par, [gamma2_0,km_0], args=(x,N,M,D0,kmin,kmax,gamma1),xtol=10**(-6),ftol=10**(-6),disp=0,full_output=1)
    result = minimize(
        func_mle_disc_2expzipf_3par, 
        [gamma1_0,gamma2_0,km_0], 
        args=(x,N,M,D0,kmin,kmax),
        # bounds = ((1.0,None),(1.,None)),
        options = {'disp':False},
        method=method)
    # convergence message 0...good,1...bad
    # warnflag = result[4]
    warnflag = result['success']
    if warnflag != True:
        print('No convergence in maximizing likelihood!')
    return result



## fit only 2 parameters
def mle_disc_minmax_optimize_2expzipf_2par(x,kmin,kmax,gamma1,gamma2_0,km_0,method = 'Nelder-Mead'):
    N = float(len(x)) #types
    M = float(sum(x)) #tokens
    x = np.sort(x)[::-1]
    rlog = np.log(np.arange(N)+1)
    
    D0 = sum((x/M)*rlog)
    # result = fmin(func_mle_disc_2expzipf_2par, [gamma2_0,km_0], args=(x,N,M,D0,kmin,kmax,gamma1),xtol=10**(-6),ftol=10**(-6),disp=0,full_output=1)
    result = minimize(
        func_mle_disc_2expzipf_2par, 
        [gamma2_0,km_0], 
        args=(x,N,M,D0,kmin,kmax,gamma1),
        # bounds = ((1.0,None),(1.,None)),
        options = {'disp':False},
        method=method)
    # convergence message 0...good,1...bad
    # warnflag = result[4]
    warnflag = result['success']
    if warnflag != True:
        print('No convergence in maximizing likelihood!')
    return result

def func_mle_disc_2expzipf_2par(params,x,N,M,D0,kmin,kmax,gamma1):
    gamma2 = params[0]
    if kmax==None:
        eps=10.0**(-6)
        if gamma2 <= 1.:
            gamma2=1. + eps
    km = int(np.abs(params[1]))
    # print(gamma2,km,gamma1,N)
    if kmax == None:
        C = zeta_minmax(gamma1,kmin,km+1) + km**(gamma2-gamma1)*zeta_minmax(gamma2,km+1,kmax) 
    else:
#         print(zeta_minmax(gamma1,kmin,km+1))
#         print(zeta_minmax(gamma2,km+1,kmax+1))
        C = zeta_minmax(gamma1,kmin,km+1) + km**(gamma2-gamma1)*zeta_minmax(gamma2,km+1,kmax+1)
    if km > N:
        summe1 = sum((x/M)*np.log(np.arange(N)+1))
    else:
#         print(km)
        summe1 = sum((x[:int(km)]/M)*np.log(np.arange(int(km))+1))
    summe2 = D0 - summe1
    summe3 = sum((x[int(km)+1:]/M))
    L = np.log(C) + gamma1*summe1 + gamma2*summe2 - summe3*(gamma2-gamma1)*np.log(km)
    return L

def func_mle_disc_2expzipf_3par(params,x,N,M,D0,kmin,kmax):
    gamma1 = params[0]
    gamma2 = params[1]
    if kmax==None:
        eps=10.0**(-6)
        if gamma2 <= 1.:
            gamma2=1. + eps
    km = int(np.abs(params[2]))
    # print(gamma2,km,gamma1,N)
    if kmax == None:
        C = zeta_minmax(gamma1,kmin,km+1) + km**(gamma2-gamma1)*zeta_minmax(gamma2,km+1,kmax) 
    else:
#         print(zeta_minmax(gamma1,kmin,km+1))
#         print(zeta_minmax(gamma2,km+1,kmax+1))
        C = zeta_minmax(gamma1,kmin,km+1) + km**(gamma2-gamma1)*zeta_minmax(gamma2,km+1,kmax+1)
    if km > N:
        summe1 = sum((x/M)*np.log(np.arange(N)+1))
    else:
#         print(km)
        summe1 = sum((x[:int(km)]/M)*np.log(np.arange(int(km))+1))
    summe2 = D0 - summe1
    summe3 = sum((x[int(km)+1:]/M))
    L = np.log(C) + gamma1*summe1 + gamma2*summe2 - summe3*(gamma2-gamma1)*np.log(km)
    return L

# %%
def fit_double_powerlaw(counts,nrep,rmin_fit,rmax_fit):
    '''Fits the double power-law model'''
    gamma1 = 1.0 # gamma1 is fixed
    L = np.inf # normalized negative log-likelihood
    gamma2 = -1
    rm = -1
    # range to sample initial conditions for the free parameters
    x1_0 = (1.,3.)
    x2_0 = (1.,10**4)
    n_success = 0
    np.random.seed(41)
    for i_nrep in range(nrep):

        gamma2_0 =  np.random.random()*( x1_0[1]-x1_0[0]  ) + x1_0[0] 
        rm_0 = int(  np.random.random()*( x2_0[1]-x2_0[0]  ) + x2_0[0] )
    #     print(gamma2_0,rm_0)
        result = mle_disc_minmax_optimize_2expzipf_3par(counts,rmin_fit,rmax_fit,gamma1,gamma2_0,rm_0)

        gamma1_tmp, gamma2_tmp,rm_tmp = result['x']
        L_tmp = result['fun']
        warnflag = result['success']
        if warnflag==True:
            n_success+=1
        if L_tmp<L and warnflag==True:
            L=L_tmp
            gamma1 = gamma1_tmp
            gamma2 = gamma2_tmp
            rm = rm_tmp
    return([gamma1, gamma2,rm],L,n_success)

# %% [markdown]
# # Fitting Double Power Law

# %%
nrep=20
rmin_Fit=1
rmax_Fit=None
counts = freq_list
Result = fit_double_powerlaw(counts, nrep, rmin_Fit, rmax_Fit)
print(Result)
# Out:
# ([0.9837139545346791, 2.369909618532549, 3243.981453305426], 6.5978834498863055, 20)

# %%
Result[0][0]
# Out:
# 0.9837139545346791

# %% [markdown]
# # Simulate Data

# %%
def produce_simulated_data(Gamma1, Gamma2, Knee, Number_of_data_points):
    data_points = []
    rank = []
    for i in range(1,Number_of_data_points):
        if i <= Knee:
            x = i**-Gamma1
        else:
            x = Knee**(Gamma2-Gamma1) * i**-Gamma2
        
        data_points.append(x)
        rank.append(i)
    
    return data_points, rank

# %%
Gamma1 = Result[0][0]
Gamma2 = Result[0][1]
Knee = Result[0][2]
Number_of_data_points = len(freq_list)

sim_freqs, sim_ranks = produce_simulated_data(Gamma1, Gamma2, Knee, Number_of_data_points)

# %% [markdown]
# # Normalise Datasets for Comparison
#
# - put frequencies in the 0 to 1 range

# %%
def normalisation(LIST):
    normed_list = np.array(LIST) / sum(LIST)
    return normed_list

# %%
freq_list_normed = normalisation(freq_list)
sim_freqs_normed = normalisation(sim_freqs)

# %%
len(freq_list)
# Out:
# 15630

# %% [markdown]
# # Plot the Double Power Law Fit against Data

# %%
f,ax = plt.subplots()
ax.scatter(rank_list, freq_list_normed, label = "data")
ax.plot(sim_ranks, sim_freqs_normed, label = "fit", color='red', alpha=0.5)
ax.set_xlabel('Word Rank')
ax.set_ylabel('Word Frequency')
ax.set_xscale("log")
ax.set_xlim(1,23000)
ax.set_ylim(0.000001,0.2)
ax.set_yscale("log")
ax.set_title("Zipf's Law in the TEDLIUM corpus")
# Out:
# Text(0.5, 1.0, "Zipf's Law in the TEDLIUM corpus")

# %%
Document_Size = sum(freq_list)
Vocab = len(freq_list)
print("Doc Size:", Document_Size)
print("Vocab:", Vocab)
# Out:
# Doc Size: 265000
# Vocab: 15630

# %%
word_count
# Out:
# [('the', 13383),
#  ('and', 9436),
#  ('to', 7557),
#  ('of', 6891),
#  ('a', 6538),
#  ('that', 5330),
#  ('in', 4673),
#  ('i', 4659),
#  ('is', 4492),
#  ('you', 4229),
#  ('we', 3862),
#  ('this', 3570),
#  ('it', 3222),
#  ('so', 2830),
#  ('was', 1964),
#  ('have', 1837),
#  ('are', 1716),
#  ('they', 1716),
#  ('for', 1694),
#  ('what', 1663),
#  ('but', 1663),
#  ('on', 1582),
#  ('with', 1427),
#  ('one', 1415),
#  ("it's", 1391),
#  ('about', 1390),
#  ('can', 1286),
#  ('as', 1227),
#  ('all', 1199),
#  ('at', 1158),
#  ('be', 1146),
#  ('do', 1145),
#  ('not', 1093),
#  ('if', 1058),
#  ('now', 1015),
#  ('there', 977),
#  ('from', 964),
#  ('like', 963),
#  ('my', 961),
#  ('people', 958),
#  ('these', 926),
#  ('he', 924),
#  ('know', 895),
#  ('when', 892),
#  ("'s", 889),
#  ('just', 843),
#  ('out', 834),
#  ('very', 833),
#  ('an', 793),
#  ('here', 788),
#  ('because', 781),
#  ('see', 774),
#  ('think', 769),
#  ('our', 746),
#  ('or', 726),
#  ('how', 725),
#  ('up', 721),
#  ('me', 711),
#  ('had', 704),
#  ('going', 700),
#  ('by', 698),
#  ('which', 694),
#  ('really', 691),
#  ('then', 683),
#  ('them', 653),
#  ('would', 630),
#  ('more', 614),
#  ("that's", 609),
#  ('get', 585),
#  ('two', 585),
#  ('your', 574),
#  ('were', 570),
#  ('some', 562),
#  ("i'm", 549),
#  ('who', 545),
#  ('actually', 545),
#  ('world', 529),
#  ('time', 528),
#  ('things', 527),
#  ('has', 525),
#  ('their', 522),
#  ('way', 501),
#  ("don't", 494),
#  ('us', 487),
#  ('years', 480),
#  ('go', 478),
#  ('will', 472),
#  ('into', 467),
#  ("we're", 465),
#  ('well', 462),
#  ('want', 460),
#  ('other', 442),
#  ('could', 440),
#  ('said', 430),
#  ('make', 427),
#  ('no', 419),
#  ('first', 417),
#  ('where', 416),
#  ('little', 399),
#  ('look', 392),
#  ('those', 390),
#  ('been', 389),
#  ('thing', 382),
#  ('got', 378),
#  ('also', 378),
#  ('something', 373),
#  ('kind', 372),
#  ('say', 371),
#  ('new', 360),
#  ('much', 355),
#  ('right', 343),
#  ('three', 343),
#  ('back', 337),
#  ('most', 330),
#  ('work', 323),
#  ('many', 323),
#  ('life', 318),
#  ('than', 318),
#  ("there's", 311),
#  ('she', 306),
#  ('over', 305),
#  ('why', 301),
#  ('take', 300),
#  ('hundred', 299),
#  ('lot', 297),
#  ('down', 297),
#  ("you're", 295),
#  ('need', 292),
#  ('only', 289),
#  ('his', 288),
#  ('did', 285),
#  ('around', 282),
#  ('five', 281),
#  ('good', 277),
#  ('put', 274),
#  ("they're", 271),
#  ('thousand', 271),
#  ('come', 253),
#  ('even', 247),
#  ("we've", 243),
#  ('let', 238),
#  ('same', 237),
#  ('doing', 230),
#  ('called', 224),
#  ('through', 223),
#  ('last', 222),
#  ('talk', 219),
#  ('great', 219),
#  ('another', 218),
#  ('being', 215),
#  ('different', 215),
#  ('tell', 211),
#  ('use', 211),
#  ('idea', 210),
#  ('year', 210),
#  ('twenty', 209),
#  ('every', 207),
#  ("i've", 204),
#  ('sort', 203),
#  ('made', 203),
#  ('after', 202),
#  ('went', 201),
#  ('thought', 198),
#  ('point', 195),
#  ('day', 190),
#  ('fact', 190),
#  ('her', 190),
#  ('came', 189),
#  ('start', 187),
#  ('four', 185),
#  ('show', 184),
#  ('find', 183),
#  ('important', 182),
#  ('course', 178),
#  ('any', 176),
#  ('started', 174),
#  ('big', 171),
#  ('ago', 171),
#  ('today', 170),
#  ('change', 170),
#  ("didn't", 169),
#  ('long', 167),
#  ('part', 167),
#  ('again', 166),
#  ('human', 166),
#  ('problem', 165),
#  ('off', 161),
#  ('own', 160),
#  ('few', 158),
#  ('ten', 156),
#  ('never', 156),
#  ('next', 156),
#  ('before', 156),
#  ('does', 155),
#  ('system', 155),
#  ('each', 155),
#  ('story', 154),
#  ('whole', 154),
#  ('should', 154),
#  ('try', 152),
#  ('percent', 151),
#  ('mean', 150),
#  ("can't", 150),
#  ('used', 147),
#  ('brain', 146),
#  ('give', 145),
#  ('might', 145),
#  ('technology', 145),
#  ('its', 143),
#  ("what's", 142),
#  ('better', 141),
#  ('him', 140),
#  ('love', 140),
#  ('second', 139),
#  ('able', 139),
#  ('believe', 139),
#  ('million', 139),
#  ('bit', 138),
#  ('place', 138),
#  ('design', 138),
#  ('real', 137),
#  ('together', 136),
#  ('maybe', 134),
#  ('wanted', 134),
#  ('still', 134),
#  ('question', 134),
#  ('too', 132),
#  ('looking', 130),
#  ('took', 129),
#  ('between', 128),
#  ('live', 128),
#  ('old', 127),
#  ('may', 127),
#  ('end', 127),
#  ("i'd", 127),
#  ('call', 126),
#  ('trying', 124),
#  ('six', 123),
#  ('done', 123),
#  ("doesn't", 122),
#  ('thirty', 122),
#  ('sense', 121),
#  ('stuff', 121),
#  ('left', 119),
#  ('high', 119),
#  ('water', 118),
#  ('away', 116),
#  ('example', 116),
#  ('understand', 113),
#  ('talking', 113),
#  ('always', 112),
#  ('quite', 112),
#  ('person', 111),
#  ('thinking', 111),
#  ('working', 111),
#  ('become', 111),
#  ('found', 110),
#  ('number', 109),
#  ('kids', 109),
#  ('feel', 107),
#  ('getting', 107),
#  ('women', 106),
#  ('building', 105),
#  ('side', 103),
#  ('city', 103),
#  ('power', 103),
#  ('comes', 102),
#  ('times', 102),
#  ('data', 102),
#  ('create', 101),
#  ('help', 101),
#  ('enough', 101),
#  ('ideas', 101),
#  ('money', 100),
#  ('man', 100),
#  ('fifty', 100),
#  ('everything', 100),
#  ('food', 99),
#  ('means', 99),
#  ('school', 99),
#  ('small', 99),
#  ('earth', 99),
#  ('happened', 98),
#  ('pretty', 98),
#  ('probably', 98),
#  ('says', 98),
#  ('energy', 98),
#  ('having', 96),
#  ('interesting', 95),
#  ('experience', 94),
#  ('seven', 94),
#  ('coming', 93),
#  ('once', 93),
#  ('goes', 93),
#  ('book', 93),
#  ('country', 92),
#  ('saying', 92),
#  ('across', 91),
#  ('days', 91),
#  ('space', 91),
#  ('best', 91),
#  ('dollars', 90),
#  ("i'll", 90),
#  ('happens', 90),
#  ('hand', 90),
#  ('basically', 89),
#  ('move', 89),
#  ('eight', 89),
#  ("you've", 88),
#  ('children', 88),
#  ('ever', 88),
#  ('half', 88),
#  ('mind', 87),
#  ('light', 87),
#  ('project', 86),
#  ('often', 85),
#  ('far', 85),
#  ('computer', 85),
#  ('seen', 85),
#  ('saw', 85),
#  ('making', 84),
#  ('am', 84),
#  ('build', 84),
#  ('ok', 84),
#  ('africa', 83),
#  ('future', 82),
#  ('asked', 82),
#  ('picture', 82),
#  ('told', 82),
#  ('simple', 82),
#  ('forty', 82),
#  ('such', 81),
#  ('less', 81),
#  ('process', 81),
#  ('problems', 81),
#  ('both', 80),
#  ('room', 80),
#  ('guy', 80),
#  ('using', 80),
#  ('science', 80),
#  ('happen', 80),
#  ('planet', 80),
#  ('bad', 79),
#  ('sure', 79),
#  ('play', 79),
#  ('places', 79),
#  ('reason', 79),
#  ('business', 79),
#  ('set', 78),
#  ('within', 78),
#  ('looks', 77),
#  ('anything', 77),
#  ('without', 77),
#  ('body', 77),
#  ('couple', 77),
#  ('nine', 76),
#  ('built', 76),
#  ('true', 76),
#  ('ask', 76),
#  ('billion', 75),
#  ('though', 75),
#  ('makes', 75),
#  ('moment', 75),
#  ('health', 74),
#  ('case', 74),
#  ('war', 73),
#  ('everybody', 73),
#  ('since', 73),
#  ('social', 73),
#  ('while', 73),
#  ('yet', 73),
#  ('bring', 73),
#  ('hard', 73),
#  ('nothing', 73),
#  ('ourselves', 72),
#  ('later', 72),
#  ('top', 72),
#  ('remember', 72),
#  ('looked', 72),
#  ('living', 71),
#  ('information', 71),
#  ('turns', 71),
#  ('must', 71),
#  ('nature', 70),
#  ('heard', 70),
#  ('amazing', 70),
#  ('keep', 70),
#  ('s', 69),
#  ('home', 69),
#  ('along', 69),
#  ('ways', 69),
#  ('kinds', 68),
#  ('group', 68),
#  ('young', 68),
#  ('line', 68),
#  ('order', 67),
#  ('whether', 67),
#  ('okay', 67),
#  ('mother', 67),
#  ('god', 67),
#  ('completely', 67),
#  ("'t", 67),
#  ('company', 67),
#  ('child', 66),
#  ('middle', 66),
#  ('music', 66),
#  ('happening', 66),
#  ('learn', 66),
#  ('large', 66),
#  ('model', 66),
#  ('figure', 66),
#  ('game', 66),
#  ('beginning', 65),
#  ('yes', 65),
#  ('particular', 65),
#  ('hope', 65),
#  ('ones', 65),
#  ('fifteen', 65),
#  ('works', 65),
#  ('piece', 64),
#  ('thank', 64),
#  ('community', 64),
#  ('family', 64),
#  ('area', 64),
#  ('read', 64),
#  ('already', 64),
#  ('possible', 64),
#  ('third', 64),
#  ('else', 64),
#  ('someone', 64),
#  ('imagine', 63),
#  ('animals', 63),
#  ('natural', 63),
#  ('inside', 63),
#  ('heart', 63),
#  ('somebody', 62),
#  ('single', 62),
#  ('stories', 62),
#  ('words', 62),
#  ('history', 61),
#  ('age', 61),
#  ('wrong', 61),
#  ('species', 61),
#  ('form', 61),
#  ('state', 61),
#  ('u', 60),
#  ('ted', 60),
#  ('sound', 60),
#  ('states', 60),
#  ('car', 60),
#  ('taken', 59),
#  ('job', 59),
#  ('finally', 59),
#  ('oil', 59),
#  ('decided', 59),
#  ('cells', 59),
#  ('myself', 59),
#  ('learned', 59),
#  ('under', 59),
#  ("isn't", 59),
#  ('guys', 59),
#  ('entire', 58),
#  ('public', 58),
#  ('house', 58),
#  ('knew', 58),
#  ('head', 58),
#  ('happy', 58),
#  ('answer', 58),
#  ('amount', 58),
#  ('matter', 57),
#  ('view', 57),
#  ('open', 57),
#  ('tried', 57),
#  ('moving', 57),
#  ('face', 57),
#  ('self', 57),
#  ('video', 57),
#  ('gone', 57),
#  ('stop', 57),
#  ('universe', 57),
#  ('oh', 57),
#  ('lots', 57),
#  ('minutes', 56),
#  ('exactly', 56),
#  ('seeing', 56),
#  ('level', 56),
#  ('hours', 56),
#  ("you'll", 56),
#  ('free', 56),
#  ('men', 56),
#  ('months', 56),
#  ('lives', 55),
#  ('american', 55),
#  ('run', 55),
#  ('students', 55),
#  ('word', 55),
#  ('government', 55),
#  ('beautiful', 55),
#  ('sometimes', 55),
#  ('gets', 54),
#  ('research', 54),
#  ('environment', 54),
#  ('turn', 54),
#  ('interested', 53),
#  ('based', 53),
#  ('cost', 53),
#  ('perhaps', 53),
#  ('worked', 53),
#  ('past', 53),
#  ('york', 53),
#  ('gave', 53),
#  ('least', 53),
#  ('culture', 52),
#  ('countries', 52),
#  ("wasn't", 52),
#  ('wonderful', 52),
#  ('name', 51),
#  ('care', 51),
#  ("they've", 51),
#  ('until', 51),
#  ('low', 51),
#  ('front', 51),
#  ('seems', 51),
#  ('size', 50),
#  ('difference', 50),
#  ('feet', 50),
#  ('began', 50),
#  ('taking', 50),
#  ('felt', 50),
#  ('education', 50),
#  ('created', 50),
#  ('green', 49),
#  ('machine', 49),
#  ('america', 49),
#  ('ninety', 49),
#  ('news', 49),
#  ('talked', 49),
#  ('almost', 49),
#  ('theory', 49),
#  ('during', 49),
#  ('sitting', 49),
#  ('friend', 49),
#  ('market', 49),
#  ('realized', 48),
#  ('parts', 48),
#  ('society', 48),
#  ('scale', 48),
#  ('powerful', 48),
#  ('everyone', 48),
#  ('leave', 48),
#  ('itself', 48),
#  ("we'll", 48),
#  ('certain', 48),
#  ('huge', 48),
#  ('united', 48),
#  ('won', 48),
#  ('global', 48),
#  ('share', 47),
#  ('stand', 47),
#  ('early', 47),
#  ('century', 47),
#  ('study', 47),
#  ('walk', 47),
#  ('south', 47),
#  ('internet', 47),
#  ('deep', 47),
#  ('write', 47),
#  ('given', 47),
#  ('longer', 47),
#  ('whatever', 47),
#  ('wrote', 47),
#  ('image', 46),
#  ('brought', 46),
#  ('dna', 46),
#  ('sixty', 46),
#  ('control', 46),
#  ('rules', 46),
#  ('outside', 46),
#  ('rest', 46),
#  ('morning', 46),
#  ("she's", 45),
#  ('art', 45),
#  ('instead', 45),
#  ('force', 45),
#  ('nice', 45),
#  ('night', 45),
#  ('needs', 45),
#  ('woman', 45),
#  ('father', 45),
#  ('easy', 44),
#  ('watch', 44),
#  ('needed', 44),
#  ('deal', 44),
#  ('terms', 44),
#  ('rather', 44),
#  ('miles', 44),
#  ('media', 44),
#  ('air', 44),
#  ('systems', 44),
#  ('common', 44),
#  ('per', 44),
#  ('seventy', 44),
#  ('bottom', 44),
#  ('eighty', 44),
#  ('spent', 44),
#  ('language', 44),
#  ('starting', 44),
#  ('center', 43),
#  ('shows', 43),
#  ('test', 43),
#  ('cities', 43),
#  ('simply', 43),
#  ('zero', 43),
#  ('india', 43),
#  ('opportunity', 43),
#  ('close', 43),
#  ('turned', 43),
#  ('themselves', 43),
#  ('red', 43),
#  ('became', 42),
#  ('buy', 42),
#  ('approach', 42),
#  ('land', 42),
#  ('local', 42),
#  ('ocean', 42),
#  ('device', 42),
#  ('eyes', 42),
#  ('technologies', 42),
#  ('stage', 41),
#  ('china', 41),
#  ('knows', 41),
#  ('yeah', 41),
#  ('evolution', 41),
#  ('against', 41),
#  ('met', 41),
#  ('surface', 41),
#  ('books', 40),
#  ('hear', 40),
#  ('focus', 40),
#  ('showed', 40),
#  ('designed', 40),
#  ('designers', 40),
#  ('short', 40),
#  ('known', 40),
#  ('field', 40),
#  ('quickly', 40),
#  ('yourself', 40),
#  ("couldn't", 40),
#  ('either', 40),
#  ('white', 40),
#  ('incredible', 40),
#  ('fun', 39),
#  ('film', 39),
#  ('friends', 39),
#  ('companies', 39),
#  ('population', 39),
#  ('reasons', 39),
#  ('nobody', 39),
#  ('full', 39),
#  ('experiment', 39),
#  ('animal', 39),
#  ('team', 38),
#  ('feeling', 38),
#  ('phone', 38),
#  ('recently', 38),
#  ('learning', 38),
#  ('cannot', 38),
#  ('games', 38),
#  ('structure', 38),
#  ('growing', 38),
#  ('asking', 38),
#  ('week', 38),
#  ('explain', 38),
#  ('disease', 38),
#  ('projects', 38),
#  ('changed', 38),
#  ('map', 38),
#  ('teach', 38),
#  ('twelve', 38),
#  ('beyond', 37),
#  ('numbers', 37),
#  ('economy', 37),
#  ('step', 37),
#  ('tools', 37),
#  ('resources', 37),
#  ('camera', 37),
#  ('exciting', 37),
#  ('ability', 37),
#  ('others', 37),
#  ('behavior', 37),
#  ('lost', 37),
#  ('seem', 37),
#  ('industry', 37),
#  ('showing', 37),
#  ('hundreds', 37),
#  ('running', 37),
#  ('certainly', 37),
#  ('growth', 36),
#  ('grow', 36),
#  ('spend', 36),
#  ('begin', 36),
#  ('becomes', 36),
#  ('lose', 36),
#  ('law', 36),
#  ('cancer', 36),
#  ('complex', 36),
#  ('excited', 36),
#  ('difficult', 36),
#  ('somehow', 35),
#  ('nineteen', 35),
#  ('lead', 35),
#  ('sun', 35),
#  ('break', 35),
#  ('allow', 35),
#  ('modern', 35),
#  ('meet', 35),
#  ('effect', 35),
#  ('re', 35),
#  ('chance', 35),
#  ('questions', 35),
#  ('network', 35),
#  ('dark', 35),
#  ('speak', 35),
#  ('economic', 35),
#  ('developed', 34),
#  ('thousands', 34),
#  ('sea', 34),
#  ('parents', 34),
#  ('materials', 34),
#  ('walking', 34),
#  ('movie', 34),
#  ('takes', 33),
#  ('cell', 33),
#  ('suddenly', 33),
#  ('town', 33),
#  ('eat', 33),
#  ('fall', 33),
#  ('higher', 33),
#  ('putting', 33),
#  ('non', 33),
#  ('lived', 33),
#  ('mars', 33),
#  ('challenge', 33),
#  ('slide', 33),
#  ("haven't", 33),
#  ('shape', 33),
#  ('university', 33),
#  ('solar', 33),
#  ('realize', 33),
#  ('development', 33),
#  ('changes', 33),
#  ('speed', 33),
#  ('mass', 33),
#  ('fast', 33),
#  ('present', 32),
#  ('listen', 32),
#  ('audience', 32),
#  ('cool', 32),
#  ('object', 32),
#  ('generation', 32),
#  ('involved', 32),
#  ('behind', 32),
#  ('girls', 32),
#  ('indeed', 32),
#  ('areas', 32),
#  ('program', 32),
#  ('reading', 32),
#  ('playing', 32),
#  ('pattern', 32),
#  ('series', 32),
#  ('normal', 32),
#  ('relationship', 32),
#  ('telling', 32),
#  ('pictures', 32),
#  ('digital', 32),
#  ('discovered', 31),
#  ('supposed', 31),
#  ('anyway', 31),
#  ('potential', 31),
#  ('creating', 31),
#  ('named', 31),
#  ('product', 31),
#  ('wish', 31),
#  ('happiness', 31),
#  ('key', 31),
#  ('site', 31),
#  ('web', 31),
#  ('nuclear', 31),
#  ('climate', 31),
#  ('died', 31),
#  ('measure', 31),
#  ('millions', 31),
#  ('english', 31),
#  ('black', 31),
#  ('pay', 31),
#  ('fish', 30),
#  ('ground', 30),
#  ('lab', 30),
#  ('eighteen', 30),
#  ('die', 30),
#  ('eleven', 30),
#  ('north', 30),
#  ('quality', 30),
#  ('wall', 30),
#  ('computers', 30),
#  ('east', 30),
#  ('born', 30),
#  ('solution', 30),
#  ('developing', 30),
#  ('teacher', 30),
#  ('notice', 30),
#  ('towards', 30),
#  ('ended', 30),
#  ('major', 30),
#  ('trees', 30),
#  ('led', 30),
#  ('blue', 29),
#  ('type', 29),
#  ('weeks', 29),
#  ('similar', 29),
#  ('although', 29),
#  ('grew', 29),
#  ('hit', 29),
#  ('square', 29),
#  ('value', 29),
#  ('watching', 29),
#  ('hold', 29),
#  ('wonder', 29),
#  ('d', 29),
#  ('changing', 29),
#  ('humans', 29),
#  ('further', 29),
#  ('baby', 29),
#  ('reach', 29),
#  ('sit', 29),
#  ('hands', 29),
#  ('values', 29),
#  ('develop', 29),
#  ('basic', 29),
#  ('issue', 29),
#  ('national', 29),
#  ('complicated', 28),
#  ('ice', 28),
#  ('creative', 28),
#  ("wouldn't", 28),
#  ('month', 28),
#  ('spread', 28),
#  ('moved', 28),
#  ('version', 28),
#  ('schools', 28),
#  ('greatest', 28),
#  ('soon', 28),
#  ('paper', 28),
#  ('chinese', 28),
#  ('special', 28),
#  ('office', 28),
#  ('meant', 27),
#  ('pieces', 27),
#  ('fantastic', 27),
#  ('western', 27),
#  ('period', 27),
#  ('machines', 27),
#  ('software', 27),
#  ('giving', 27),
#  ('clear', 27),
#  ('class', 27),
#  ('truly', 27),
#  ('images', 27),
#  ('training', 27),
#  ('organization', 27),
#  ('main', 27),
#  ("they'll", 27),
#  ('largest', 27),
#  ('scientists', 27),
#  ('song', 27),
#  ('security', 27),
#  ('above', 27),
#  ('doctor', 27),
#  ('situation', 27),
#  ('result', 27),
#  ('several', 27),
#  ('available', 27),
#  ('earlier', 27),
#  ('goal', 27),
#  ('movement', 27),
#  ('innovation', 27),
#  ('average', 27),
#  ('continue', 26),
#  ('interest', 26),
#  ('dollar', 26),
#  ('moon', 26),
#  ('organisms', 26),
#  ('material', 26),
#  ('anybody', 26),
#  ('tree', 26),
#  ('remarkable', 26),
#  ('table', 26),
#  ('stay', 26),
#  ('support', 26),
#  ('girl', 26),
#  ('reality', 26),
#  ('follow', 26),
#  ('buildings', 26),
#  ('village', 26),
#  ('beauty', 26),
#  ("we'd", 26),
#  ('vision', 26),
#  ('literally', 26),
#  ('solve', 26),
#  ('revolution', 26),
#  ('boy', 26),
#  ("you'd", 26),
#  ('produce', 26),
#  ('impact', 26),
#  ('message', 26),
#  ('robots', 26),
#  ('cut', 26),
#  ('forms', 26),
#  ('truth', 26),
#  ('fly', 26),
#  ('west', 26),
#  ('individual', 25),
#  ('written', 25),
#  ('wants', 25),
#  ('fundamental', 25),
#  ('solutions', 25),
#  ('allowed', 25),
#  ('total', 25),
#  ('physical', 25),
#  ('worst', 25),
#  ('blood', 25),
#  ('fine', 25),
#  ('poor', 25),
#  ('bought', 25),
#  ('shown', 25),
#  ('stars', 25),
#  ('rate', 25),
#  ('sounds', 25),
#  ('journey', 25),
#  ('gives', 25),
#  ('street', 25),
#  ('familiar', 25),
#  ('sent', 25),
#  ('especially', 25),
#  ('personal', 25),
#  ('meaning', 25),
#  ('google', 25),
#  ('general', 25),
#  ('figured', 25),
#  ('kept', 25),
#  ('access', 25),
#  ('rich', 24),
#  ('objects', 24),
#  ('fourth', 24),
#  ('student', 24),
#  ('hiv', 24),
#  ('examples', 24),
#  ('conditions', 24),
#  ('successful', 24),
#  ('extremely', 24),
#  ('guess', 24),
#  ('robot', 24),
#  ('list', 24),
#  ('among', 24),
#  ('allows', 24),
#  ('reduce', 24),
#  ('term', 24),
#  ('add', 24),
#  ('biology', 24),
#  ('carbon', 24),
#  ('evolved', 24),
#  ('obviously', 24),
#  ('pick', 24),
#  ('bunch', 24),
#  ('act', 24),
#  ('worth', 24),
#  ('points', 24),
#  ('death', 24),
#  ('touch', 24),
#  ('direction', 24),
#  ('starts', 24),
#  ('final', 24),
#  ('museum', 24),
#  ('train', 24),
#  ('extraordinary', 24),
#  ('college', 24),
#  ('lines', 24),
#  ('floor', 23),
#  ('flying', 23),
#  ('teaching', 23),
#  ('studies', 23),
#  ('standing', 23),
#  ('lower', 23),
#  ('moral', 23),
#  ('teachers', 23),
#  ('traditional', 23),
#  ('fear', 23),
#  ('online', 23),
#  ('critical', 23),
#  ('character', 23),
#  ...]

# %%
# The probability of seeing the word "The"
13318/265000
# Out:
# 0.05025660377358491
